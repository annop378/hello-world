# %% [markdown]
# ### 動態公車調度模型簡介
#
# ##### 研究問題
# >問題：目前固定班次的公車無法應付乘客突然暴增的情形，故需要藉由電子票證的歷史資料，以及影像辨識的即時資料，搭配預測模式與時空路網模型，提前告知depot發加班車的合適時間點。
#
# >描述：針對高雄市公車路網，利用過去電子票證資料預測站間量，與部份車站設置監視器的影像辨識系統，所提供即時的候車人數預測上下車人數。由於高雄市公車去回之候車空間是分開的，在此當不同站點做區隔。
#
# >輸入：
# 	預測時間t至t+Δt_2之每兩站的站間量(由預測得到的上下車人數推得)
# 	在有設監視器的車站預測時間t至t+Δt_2該站的乘客抵達率，未設監視器的車站則透過過去票證資料補齊。
# 	預測時間段期間，站點間的旅行時間
#
# >旅客行為：等太久會隨時間依比例流失，Δt_2假定一小時.
#
# >業者行為：派車、有賺錢才發車(加班車不會被補助，原班次仍有政府補助)。
#
# >目標式：最大化利潤(票證收入-發車成本)。
#
# >輸出：指令形式(每一個時階發車與否)，t至t+Δt_2
# 	目前有兩台影像辨識攝影機與三條公車路線(如下圖示意圖)
#
# ##### 研究假設
# 	暫不考慮車隊數
# 	假設加班車容量遠大於加班車之需求(故加班車不會有容量上限，僅原班次有容量上限，由可接的擁擠量-站間量而得)
#
# ##### 解決方案
# 建立時空路網模型，以解決派遣公車加班車的問題。
#
# >原則
# 1.	透過模式的目標式，最大化業者派遣加班車的利潤(票證收入-發車成本)。
# 2.	透過兩大時空路網(公車加班車時空路網與乘客時空路網)確保公車加班車調度的合理性。
# ##### 時空路網概念
# >兩大路網
# 1.	公車加班車的路網：由於高雄市公車去回之候車空間是分開的，在此當不同站點做區隔。
# 2.	乘客的路網：由於無法推得乘客的迄點，故在乘客路網中所有乘客的迄點均為最後一站，並假設加班車容量遠大於加班車之需求，故不考慮加班車的容量限制。
# 在兩大時空路網中，路網圖的X軸代表站點的次序，Y軸代表預測時間段的次序。此模式中的公車加班車路網表示加班車的派遣與流動，其中的旅行arcs由事先預測得到的旅行時間參數建立(如2.3的圖所示)；乘客路網則表示對加班車有需求的乘客流動，而其中的旅行arcs同公車加班車路網中的旅行arcs，乘客路網中的demand 流失 arcs，則與其路網中旅客等候arcs同時並存，也就是當某一站點時間段有一條等候arc往下連到下個時間段，該node就會同時有一條demand 流失 arc連到sink node，以利表示乘客會隨等候時間的產生，而等比例流失(如2.4的圖所示)。
#
# ##### 模式方向
# 	本計劃案主要著重在於預測原固定班次的站間量(用預測得到的上下車人數推)與預測每站的乘客抵達率的合理性(參數)，利用可事先預測的參數建立合適的模型。
# 	由於加班車不會受到政府補助，此時空路網模式是站在業者的角度去做派遣公車加班車的決策

# %% [markdown]
# # 預測資料處理

# %% [markdown]
# >載入讀取資料的套件

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# >讀取預測資料

# %%
busfactor = pd.read_csv('testdata.csv',encoding='BIG5')
busfactor.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
busfactor.head()
# Out:
#          日期   班次  StopName_Zh_tw  StopSequence  UP  DOWN  PASSNUM  pedict_up  \
# 0  2019/7/1  900             前鎮站             1   1     0        1          3
# 1  2019/7/1  900  輕軌夢時代站(統一時代百貨)             2   0     0        1          0
# 2  2019/7/1  900            台糖物流             3   0     0        1          0
# 3  2019/7/1  900         輕軌經貿園區站             4   0     0        1          0
# 4  2019/7/1  900             正勤路             5   1     0        2          2
#
#    pedict_down  pedict_passnum  drive_passnum
# 0            0               3              3
# 1            0               2              3
# 2            0               2              3
# 3            0               2              3
# 4            0               4              5

# %% [markdown]
# >將預測資料轉成模式參數

# %%
#旅行時間
timeable={'前鎮站':'800','輕軌夢時代站(統一時代百貨)':'801','台糖物流':'802','輕軌經貿園區站':'803','正勤路':'803'
          ,'正勤社區':'804','中華復興路口':'805','中華五路':'806','新光路口(圖書總館)':'807','三多四路口':'808'
         ,'大遠百百貨(捷運三多商圈站)':'810','新光三越(捷運三多商圈站)':'811','三多三路':'812','仁愛三街口':'813'
         ,'三多復興路口':'814','三多市場(三多三路)':'815','光華路口(光華夜市)':'816','林德官(三和市場)':'816'
         ,'和平路口':'817','五權國小(三多二路)':'818','凱旋二路口':'818','國際商工':'819','三信家商':'820'
         ,'五塊厝(三多一路)':'821','輔仁路口(三多一路)':'822','中正體育場':'823','衛武營':'824','衛武營國家藝術文化中心':'825'
         ,'衛武社區':'828','鳳山行政中心(澄清路)':'830','覺民路口(澄清路)':'832','褒揚街口':'833','澄清路':'835'
         ,'大華村':'836','正修科大(澄清湖)':'838','長庚復健大樓':'844','長庚醫院':'846','澄清湖棒球場':'848'}
time=timeable.values()

# %% [markdown]
# ###### 整合投入資料

# %%
#原班次的班距(分鐘)
schedule=15
#原班次的起始時間
st=[]
for i in busfactor['班次']:
    st.append(i)
st=list(set(st))
clean=min(st)
for i,j in enumerate(st):
    st[i]-=clean
day= '2019/7/1'

# %% [markdown]
# >1. 投入：預測上車人數、下車人數、站間量

# %%
#7/1資料 busfactor.iloc[15]
m1=dict()
for i,j in enumerate(busfactor['日期']):
    if j == day:
        stop = busfactor.iloc[i]['StopName_Zh_tw']
        m1[stop]=dict()
        m1[stop]['pedict_up']=dict()
        m1[stop]['pedict_down']=dict()
        m1[stop]['drive_passnum']=dict()
for i,j in enumerate(busfactor['日期']):
    if j == day:
        stop = busfactor.iloc[i]['StopName_Zh_tw']
        for sch in st:
            if busfactor.iloc[i]['班次'] == sch+clean:
                m1[stop]['pedict_up'][sch]=busfactor['pedict_up'][i]
                m1[stop]['pedict_down'][sch] =busfactor['pedict_down'][i]
                if busfactor['drive_passnum'][i] < 0:
                    m1[stop]['drive_passnum'][sch] =busfactor['pedict_passnum'][i]
                else:
                    m1[stop]['drive_passnum'][sch] =busfactor['drive_passnum'][i]

# %%
stop=[]
for i in m1:
    stop.append(i)

# %% [markdown]
# >2.投入:旅行時間

# %%
#預測45分鐘，因為許多站間的旅行時間為一分鐘，甚至不到，因此在路網時間軸以1分鐘為一單位。
T=45
delta=1
#set K M B VA VN MTA
#觀測站點(K)
K=stop
#建立兩大路網中的node
demand=[]
for m in m1:
    for l in range(0,T):
        demand.append((m,l))

# %%
for i,j in enumerate(stop):
    if i == 0:
        m1[j]['travel_time']= 0
    else:
        m1[j]['travel_time']= int(timeable[j])-int(timeable[stop[i-1]])

# %% [markdown]
# >3.投入：抵達率

# %%
#抵達率(人/分鐘)
for i in m1:
    m1[i]['arrival_rate']=dict()
    for j in st:
        for k in range(j,j+schedule):
            m1[i]['arrival_rate'][k]=m1[i]['pedict_up'][j]/schedule
#四捨五入round()

# %% [markdown]
# ##### 建立兩大路網

# %% [markdown]
# >乘客路網

# %%
#![title](bus_network.jpg)
#<img src="bus_network.jpg" width="100%">

# %% [markdown]
# <img src="passenger_network.png" width="80%">

# %% [markdown]
# 1.等候時間的上限：透過不同起點建立一層路網做限制[迄點均假設是最後一站]
#
# 2.收入計算，針對加班車(非原班次的公車)，其所有路段的[流出-流入]*票證收入(16元)

# %%
#建立乘客路網的arc(B)
B=[]
for i in demand:
    tt = i[1]
    a=K.index(i[0])
    b=K.index(K[-1])
    t=i[1]
    for l in range(a,b):
        if a != b :
            t+= m1[K[l+1]]['travel_time']
            if t <= T:
                B.append(((K[l],tt),(K[l+1],t)))
            elif tt <= T:
                B.append(((K[l],tt),'dummy'))
            tt = t
for m in demand:
    B.append(('source',m))
    B.append((m,'sink'))
for t in range(0,T):
        B.append((('%s'%(stop[-1]),t),'dummy'))
for i in K:
    for a in range(T-1):
        B.append(((i,a),(i,a+1)))
B.append(('sink','dummy'))

# %% [markdown]
# >載入加班車模式套件

# %%
from gurobipy import *
import math

# %% [markdown]
# >公車路網

# %% [markdown]
# <img src="bus_network.jpg" width="80%">

# %%
#建立公車路網的所有arc(VV)&公車屬於加班車的載客arc(VAB)&固定班次的載客arc(SVS)
VV=tuplelist()
VAB=tuplelist()
SVS=tuplelist()
k=stop[0]
for i in range(0,T):
    VV.append(('source',(k,i)))     
VV.append(('source','sink'))
for i in range(0,T):
    for m,l in enumerate(K):
        if i != T and K[m] != K[-1]:
            if i+m1[K[m+1]]['travel_time'] <= T:
                VV.append(((l,i),(K[m+1],i+m1[K[m+1]]['travel_time'])))
                #檢查是否為原班次
                for check in st:
                    for cc in range(K.index(l)+1):
                        check+= m1[K[cc]]['travel_time']
                    if i != check:
                        VAB.append(((l,i),(K[m+1],i+m1[K[m+1]]['travel_time'])))
                    else :
                        SVS.append(((l,i),(K[m+1],i+m1[K[m+1]]['travel_time'])))
            else:
                VV.append(((l,i),'sink'))
for k in K:
    VV.append(((k,T),'sink')) 
#VS & VD
VS=['source']
VD=['sink']            
#VN       
VN=[]
for k in K:
    for t in range(0,T):
        VN.append((k,t))
#MN
MN=[]
for i in VAB:
    MN.append(i[0])
    MN.append(i[1])
MN=list(set(MN))

# %% [markdown]
# >參數

# %%
#param
rev=-16
km= 5
cc=38*km        
e=dict()
for k,j in enumerate(demand):
    e[j] = m1[j[0]]['arrival_rate'][j[1]]
        
q=10
veh=3
aa=6.0
MM=100

# %% [markdown]
# >站間量

# %% [markdown]
# ## 模型

# %% [markdown]
# >假設
# 1.	已知：原固定班次站間的乘客量、乘客到站點的抵達率、各時間段的公車旅行時間
# 2.	透過事先定義好的公車可接受載量、預測得到的資料[站間量、上下車人數]，推算原班次在站間的容量，暫不考慮車隊數。
# 3.	假設加班車容量遠大於加班車之需求，故針對加班車無容量限制。

# %% [markdown]
# <img src="indiceandsets.JPG" width="80%">

# %% [markdown]
# <img src="paramandvarandobj.JPG" width="80%">

# %%
#variable
m = Model("realcontrol_6.0")
#m.setParam('MIPGAP',0.5)
x = {}
for i in VV:
    x[i[0],i[1]] = m.addVar(vtype = GRB.INTEGER,lb=0, name = "x[%s,%s]" %(i[0],i[1]))
y = {}
for i in B:
    y[i[0],i[1]] = m.addVar(vtype = GRB.CONTINUOUS,lb=0, name = "y[%s,%s]" %(i[0],i[1]))
# Out:
# Using license file C:\Users\James\gurobi.lic
# Academic license - for non-commercial use only

# %% [markdown]
# <img src="st1.JPG" width="80%">

# %% [markdown]
# <img src="st2.jpg" width="80%">

# %% [markdown]
# (1)	在公車路網中，從source node 出去的車子數為veh
#
# (2)	在公車路網中，回到sink node的車子數為veh
#
# (3)	公車路網的流量平衡
#
# (4)	乘客路網的流量平衡
#
# (5)	乘客路網的每個時空站點抵達乘客數
#
# (6)	原班次公車的載客量不能超過車子的容量[這裡的容量為可接受壅擠量扣除站間量所剩餘的載客量]
#
# (7)	有加班車乘客才能移動
#
# (8)	乘客會因為等候而等比例流失

# %%
#obj
m.setObjective(sum((sum(y[a,h] for a,h in B if a ==j  and h != 'sink' and h != 'dummy' and a[0] != h[0] )\
            -sum(y[i,b] for i,b in B if b == j and i[0] != b[0]\
            and i != 'source'  and b != 'sink'and b[1] != T)) \
            for j in MN )*rev +\
            sum(cc*x[i[0],i[1]] for i in VV if i[0] == 'source' and i[1] != 'sink')  , GRB.MINIMIZE)

#subjectto
for i in VS:
    m.addConstr(quicksum(x[i,j] for i,j in VV.select(i,'*')) == veh)
    
for j in VD:
    m.addConstr(quicksum(x[i,j] for i,j in VV.select('*',j)) == veh)

for i in VN:
    m.addConstr(quicksum(x[h,j] for h,j in VV if h == i) - quicksum(x[j,l] for j,l in VV if l == i) == 0)
    

for i in MN:
    if i[1] <= T:
        m.addConstr(quicksum(y[h,j] for h,j in B if h==i) - quicksum(y[j,l] for j,l in B if l == i) == 0)

for a,k in enumerate(demand):
    m.addConstr(y['source',k] == e[k]*(k[1]%15))

for i in SVS:
    if i[0][1] <= T:
        if (q-m1[i[0][0]]['drive_passnum'][i[0][1]-i[0][1]%schedule]) >= 0:
            m.addConstr(y[i[0],i[1]]  <= (q-m1[i[0][0]]['drive_passnum'][i[0][1]-i[0][1]%schedule]))
        else:
            m.addConstr(y[i[0],i[1]]  <= 0)
for i in VAB:
    if i[0][1] <= T:
        m.addConstr(y[i[0],i[1]]  <= MM*x[i[0],i[1]])           
for i in B:
    if i[0][0] == i[1][0]:
        m.addConstr(aa*y[i[0],'sink'] == y[i[0],i[1]])

# %% [markdown]
# >求解

# %%
m.optimize()
for v in m.getVars():
    if v.x >= 0.01:
        print ('%s:%f' %(v.varName,v.x))
print ('objective value:%f'  %(m.objVal))
# Out:
# Gurobi Optimizer version 9.0.0 build v9.0.0rc2 (win64)
# Optimize a model with 11789 rows, 29697 columns and 28456 nonzeros
# Model fingerprint: 0x2076d549
# Variable types: 27948 continuous, 1749 integer (0 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+02]
#   Objective range  [2e+01, 6e+02]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [7e-02, 8e+00]
# Presolve removed 9952 rows and 27845 columns
# Presolve time: 0.03s
# Presolved: 1837 rows, 1852 columns, 5470 nonzeros
# Variable types: 1807 continuous, 45 integer (2 binary)
#
# Root relaxation: objective -9.217336e+03, 2819 iterations, 0.06 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0 -9217.3364    0   30          - -9217.3364      -     -    0s
# H    0     0                    -3545.789482 -9158.2856   158%     -    0s
#      0     0 -8629.5739    0   33 -3545.7895 -8629.5739   143%     -    0s
# H    0     0                    -3912.106855 -8629.5739   121%     -    0s
# H    0     0                    -4387.812134 -8629.5739  96.7%     -    0s
# H    0     0                    -4898.873702 -8629.5739  76.2%     -    0s
#      0     0 -8490.1460    0   33 -4898.8737 -8490.1460  73.3%     -    0s
#      0     0 -8473.6589    0   33 -4898.8737 -8473.6589  73.0%     -    0s
#      0     0 -8452.0199    0   34 -4898.8737 -8452.0199  72.5%     -    0s
#      0     0 -8451.8006    0   34 -4898.8737 -8451.8006  72.5%     -    0s
#      0     0 -8450.8517    0   33 -4898.8737 -8450.8517  72.5%     -    0s
# H    0     0                    -5110.598592 -8411.1877  64.6%     -    0s
#      0     0 -8141.0029    0   32 -5110.5986 -8141.0029  59.3%     -    0s
#      0     0 -8117.4309    0   34 -5110.5986 -8117.4309  58.8%     -    0s
#      0     0 -8074.7190    0   34 -5110.5986 -8074.7190  58.0%     -    0s
#      0     0 -8070.5067    0   34 -5110.5986 -8070.5067  57.9%     -    0s
#      0     0 -8067.4582    0   34 -5110.5986 -8067.4582  57.9%     -    0s
#      0     0 -7918.7360    0   35 -5110.5986 -7918.7360  54.9%     -    0s
#      0     0 -7862.9969    0   35 -5110.5986 -7862.9969  53.9%     -    0s
#      0     0 -7846.1469    0   35 -5110.5986 -7846.1469  53.5%     -    0s
#      0     0 -7838.4658    0   35 -5110.5986 -7838.4658  53.4%     -    0s
#      0     0 -7838.4658    0   35 -5110.5986 -7838.4658  53.4%     -    0s
#      0     0 -7674.1396    0   33 -5110.5986 -7674.1396  50.2%     -    0s
#      0     0 -7656.9434    0   35 -5110.5986 -7656.9434  49.8%     -    0s
#      0     0 -7656.0785    0   36 -5110.5986 -7656.0785  49.8%     -    0s
#      0     0 -7656.0586    0   36 -5110.5986 -7656.0586  49.8%     -    0s
#      0     0 -7525.6642    0   34 -5110.5986 -7525.6642  47.3%     -    0s
#      0     0 -7493.9666    0   34 -5110.5986 -7493.9666  46.6%     -    0s
#      0     0 -7492.8901    0   34 -5110.5986 -7492.8901  46.6%     -    0s
#      0     0 -7492.8567    0   34 -5110.5986 -7492.8567  46.6%     -    0s
#      0     0 -7436.0522    0   34 -5110.5986 -7436.0522  45.5%     -    0s
#      0     0 -7428.3860    0   35 -5110.5986 -7428.3860  45.4%     -    0s
#      0     0 -7426.6506    0   35 -5110.5986 -7426.6506  45.3%     -    0s
#      0     0 -7406.2794    0   35 -5110.5986 -7406.2794  44.9%     -    0s
#      0     0 -7354.8945    0   33 -5110.5986 -7354.8945  43.9%     -    0s
#      0     0 -7349.8255    0   34 -5110.5986 -7349.8255  43.8%     -    0s
#      0     0 -7338.9653    0   34 -5110.5986 -7338.9653  43.6%     -    0s
#      0     0 -7325.8684    0   34 -5110.5986 -7325.8684  43.3%     -    0s
#      0     0 -7305.4981    0   34 -5110.5986 -7305.4981  42.9%     -    0s
#      0     2 -7305.4981    0   34 -5110.5986 -7305.4981  42.9%     -    0s
#
# Cutting planes:
#   Gomory: 9
#   Implied bound: 4
#   MIR: 310
#   Flow cover: 5
#
# Explored 851 nodes (57510 simplex iterations) in 1.55 seconds
# Thread count was 12 (of 12 available processors)
#
# Solution count 5: -5110.6 -4898.87 -4387.81 ... -3545.79
# No other solutions better than -5110.6
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective -5.110598592215e+03, best bound -5.110598592215e+03, gap 0.0000%
# x[source,('前鎮站', 1)]:1.000000
# x[source,('前鎮站', 13)]:1.000000
# x[source,('前鎮站', 27)]:1.000000
# x[('前鎮站', 1),('輕軌夢時代站(統一時代百貨)', 2)]:1.000000
# x[('輕軌夢時代站(統一時代百貨)', 2),('台糖物流', 3)]:1.000000
# x[('台糖物流', 3),('輕軌經貿園區站', 4)]:1.000000
# x[('輕軌經貿園區站', 4),('正勤路', 4)]:1.000000
# x[('正勤路', 4),('正勤社區', 5)]:1.000000
# x[('正勤社區', 5),('中華復興路口', 6)]:1.000000
# x[('中華復興路口', 6),('中華五路', 7)]:1.000000
# x[('中華五路', 7),('新光路口(圖書總館)', 8)]:1.000000
# x[('新光路口(圖書總館)', 8),('三多四路口', 9)]:1.000000
# x[('三多四路口', 9),('大遠百百貨(捷運三多商圈站)', 11)]:1.000000
# x[('大遠百百貨(捷運三多商圈站)', 11),('新光三越(捷運三多商圈站)', 12)]:1.000000
# x[('新光三越(捷運三多商圈站)', 12),('三多三路', 13)]:1.000000
# x[('前鎮站', 13),('輕軌夢時代站(統一時代百貨)', 14)]:1.000000
# x[('三多三路', 13),('仁愛三街口', 14)]:1.000000
# x[('輕軌夢時代站(統一時代百貨)', 14),('台糖物流', 15)]:1.000000
# x[('仁愛三街口', 14),('三多復興路口', 15)]:1.000000
# x[('台糖物流', 15),('輕軌經貿園區站', 16)]:1.000000
# x[('三多復興路口', 15),('三多市場(三多三路)', 16)]:1.000000
# x[('輕軌經貿園區站', 16),('正勤路', 16)]:1.000000
# x[('正勤路', 16),('正勤社區', 17)]:1.000000
# x[('三多市場(三多三路)', 16),('光華路口(光華夜市)', 17)]:1.000000
# x[('正勤社區', 17),('中華復興路口', 18)]:1.000000
# x[('光華路口(光華夜市)', 17),('林德官(三和市場)', 17)]:1.000000
# x[('林德官(三和市場)', 17),('和平路口', 18)]:1.000000
# x[('中華復興路口', 18),('中華五路', 19)]:1.000000
# x[('和平路口', 18),('五權國小(三多二路)', 19)]:1.000000
# x[('中華五路', 19),('新光路口(圖書總館)', 20)]:1.000000
# x[('五權國小(三多二路)', 19),('凱旋二路口', 19)]:1.000000
# x[('凱旋二路口', 19),('國際商工', 20)]:1.000000
# x[('新光路口(圖書總館)', 20),('三多四路口', 21)]:1.000000
# x[('國際商工', 20),('三信家商', 21)]:1.000000
# x[('三多四路口', 21),('大遠百百貨(捷運三多商圈站)', 23)]:1.000000
# x[('三信家商', 21),('五塊厝(三多一路)', 22)]:1.000000
# x[('五塊厝(三多一路)', 22),('輔仁路口(三多一路)', 23)]:1.000000
# x[('大遠百百貨(捷運三多商圈站)', 23),('新光三越(捷運三多商圈站)', 24)]:1.000000
# x[('輔仁路口(三多一路)', 23),('中正體育場', 24)]:1.000000
# x[('新光三越(捷運三多商圈站)', 24),('三多三路', 25)]:1.000000
# x[('中正體育場', 24),('衛武營', 25)]:1.000000
# x[('三多三路', 25),('仁愛三街口', 26)]:1.000000
# x[('衛武營', 25),('衛武營國家藝術文化中心', 26)]:1.000000
# x[('仁愛三街口', 26),('三多復興路口', 27)]:1.000000
# x[('衛武營國家藝術文化中心', 26),('衛武社區', 29)]:1.000000
# x[('前鎮站', 27),('輕軌夢時代站(統一時代百貨)', 28)]:1.000000
# x[('三多復興路口', 27),('三多市場(三多三路)', 28)]:1.000000
# x[('輕軌夢時代站(統一時代百貨)', 28),('台糖物流', 29)]:1.000000
# x[('三多市場(三多三路)', 28),('光華路口(光華夜市)', 29)]:1.000000
# x[('台糖物流', 29),('輕軌經貿園區站', 30)]:1.000000
# x[('光華路口(光華夜市)', 29),('林德官(三和市場)', 29)]:1.000000
# x[('林德官(三和市場)', 29),('和平路口', 30)]:1.000000
# x[('衛武社區', 29),('鳳山行政中心(澄清路)', 31)]:1.000000
# x[('輕軌經貿園區站', 30),('正勤路', 30)]:1.000000
# x[('正勤路', 30),('正勤社區', 31)]:1.000000
# x[('和平路口', 30),('五權國小(三多二路)', 31)]:1.000000
# x[('正勤社區', 31),('中華復興路口', 32)]:1.000000
# x[('五權國小(三多二路)', 31),('凱旋二路口', 31)]:1.000000
# x[('凱旋二路口', 31),('國際商工', 32)]:1.000000
# x[('鳳山行政中心(澄清路)', 31),('覺民路口(澄清路)', 33)]:1.000000
# x[('中華復興路口', 32),('中華五路', 33)]:1.000000
# x[('國際商工', 32),('三信家商', 33)]:1.000000
# x[('中華五路', 33),('新光路口(圖書總館)', 34)]:1.000000
# x[('三信家商', 33),('五塊厝(三多一路)', 34)]:1.000000
# x[('覺民路口(澄清路)', 33),('褒揚街口', 34)]:1.000000
# x[('新光路口(圖書總館)', 34),('三多四路口', 35)]:1.000000
# x[('五塊厝(三多一路)', 34),('輔仁路口(三多一路)', 35)]:1.000000
# x[('褒揚街口', 34),('澄清路', 36)]:1.000000
# x[('三多四路口', 35),('大遠百百貨(捷運三多商圈站)', 37)]:1.000000
# x[('輔仁路口(三多一路)', 35),('中正體育場', 36)]:1.000000
# x[('中正體育場', 36),('衛武營', 37)]:1.000000
# x[('澄清路', 36),('大華村', 37)]:1.000000
# x[('大遠百百貨(捷運三多商圈站)', 37),('新光三越(捷運三多商圈站)', 38)]:1.000000
# x[('衛武營', 37),('衛武營國家藝術文化中心', 38)]:1.000000
# x[('大華村', 37),('正修科大(澄清湖)', 39)]:1.000000
# x[('新光三越(捷運三多商圈站)', 38),('三多三路', 39)]:1.000000
# x[('衛武營國家藝術文化中心', 38),('衛武社區', 41)]:1.000000
# x[('三多三路', 39),('仁愛三街口', 40)]:1.000000
# x[('正修科大(澄清湖)', 39),('長庚復健大樓', 45)]:1.000000
# x[('仁愛三街口', 40),('三多復興路口', 41)]:1.000000
# x[('三多復興路口', 41),('三多市場(三多三路)', 42)]:1.000000
# x[('衛武社區', 41),('鳳山行政中心(澄清路)', 43)]:1.000000
# x[('三多市場(三多三路)', 42),('光華路口(光華夜市)', 43)]:1.000000
# x[('光華路口(光華夜市)', 43),('林德官(三和市場)', 43)]:1.000000
# x[('林德官(三和市場)', 43),('和平路口', 44)]:1.000000
# x[('鳳山行政中心(澄清路)', 43),('覺民路口(澄清路)', 45)]:1.000000
# x[('和平路口', 44),('五權國小(三多二路)', 45)]:1.000000
# x[('前鎮站', 45),sink]:3.000000
# y[('前鎮站', 1),('輕軌夢時代站(統一時代百貨)', 2)]:0.200000
# y[('前鎮站', 13),('輕軌夢時代站(統一時代百貨)', 14)]:10.900871
# y[('前鎮站', 27),('輕軌夢時代站(統一時代百貨)', 28)]:10.098487
# y[('輕軌夢時代站(統一時代百貨)', 2),('台糖物流', 3)]:0.100000
# y[('輕軌夢時代站(統一時代百貨)', 14),('台糖物流', 15)]:5.450436
# y[('輕軌夢時代站(統一時代百貨)', 28),('台糖物流', 29)]:5.049244
# y[('台糖物流', 3),('輕軌經貿園區站', 4)]:0.066667
# y[('台糖物流', 15),('輕軌經貿園區站', 16)]:3.633624
# y[('台糖物流', 29),('輕軌經貿園區站', 30)]:3.366162
# y[('輕軌經貿園區站', 4),('正勤路', 4)]:0.050000
# y[('輕軌經貿園區站', 16),('正勤路', 16)]:2.725218
# y[('輕軌經貿園區站', 30),('正勤路', 30)]:2.524622
# y[('正勤路', 4),('正勤社區', 5)]:0.271215
# y[('正勤路', 16),('正勤社區', 17)]:3.349364
# y[('正勤路', 30),('正勤社區', 31)]:2.713618
# y[('正勤社區', 5),('中華復興路口', 6)]:0.502277
# y[('正勤社區', 17),('中華復興路口', 18)]:3.662766
# y[('正勤社區', 31),('中華復興路口', 32)]:3.258639
# y[('中華復興路口', 6),('中華五路', 7)]:0.430523
# y[('中華復興路口', 18),('中華五路', 19)]:3.139513
# y[('中華復興路口', 32),('中華五路', 33)]:2.793119
# y[('中華五路', 7),('新光路口(圖書總館)', 8)]:0.376708
# y[('中華五路', 19),('新光路口(圖書總館)', 20)]:2.819329
# y[('中華五路', 33),('新光路口(圖書總館)', 34)]:2.709354
# y[('新光路口(圖書總館)', 8),('三多四路口', 9)]:0.529199
# y[('新光路口(圖書總館)', 20),('三多四路口', 21)]:2.746352
# y[('新光路口(圖書總館)', 34),('三多四路口', 35)]:2.606226
# y[('三多四路口', 9),('大遠百百貨(捷運三多商圈站)', 11)]:0.686205
# y[('三多四路口', 21),('大遠百百貨(捷運三多商圈站)', 23)]:2.576602
# y[('三多四路口', 35),('大遠百百貨(捷運三多商圈站)', 37)]:2.345603
# y[('大遠百百貨(捷運三多商圈站)', 11),('新光三越(捷運三多商圈站)', 12)]:1.141473
# y[('大遠百百貨(捷運三多商圈站)', 23),('新光三越(捷運三多商圈站)', 24)]:3.081211
# y[('大遠百百貨(捷運三多商圈站)', 37),('新光三越(捷運三多商圈站)', 38)]:2.875537
# y[('新光三越(捷運三多商圈站)', 12),('三多三路', 13)]:2.126466
# y[('新光三越(捷運三多商圈站)', 24),('三多三路', 25)]:3.293920
# y[('新光三越(捷運三多商圈站)', 38),('三多三路', 39)]:3.201622
# y[('三多三路', 13),('仁愛三街口', 14)]:2.523524
# y[('三多三路', 25),('仁愛三街口', 26)]:3.446277
# y[('三多三路', 39),('仁愛三街口', 40)]:3.368071
# y[('仁愛三街口', 14),('三多復興路口', 15)]:2.922823
# y[('仁愛三街口', 26),('三多復興路口', 27)]:3.403477
# y[('仁愛三街口', 40),('三多復興路口', 41)]:3.509455
# y[('三多復興路口', 15),('三多市場(三多三路)', 16)]:2.959788
# y[('三多復興路口', 27),('三多市場(三多三路)', 28)]:3.392601
# y[('三多復興路口', 41),('三多市場(三多三路)', 42)]:3.672675
# y[('三多市場(三多三路)', 16),('光華路口(光華夜市)', 17)]:2.969419
# y[('三多市場(三多三路)', 28),('光華路口(光華夜市)', 29)]:3.634767
# y[('三多市場(三多三路)', 42),('光華路口(光華夜市)', 43)]:3.863903
# y[('光華路口(光華夜市)', 17),('林德官(三和市場)', 17)]:3.117715
# y[('光華路口(光華夜市)', 29),('林德官(三和市場)', 29)]:3.894710
# y[('光華路口(光華夜市)', 43),('林德官(三和市場)', 43)]:4.065333
# y[('林德官(三和市場)', 17),('和平路口', 18)]:3.249535
# y[('林德官(三和市場)', 29),('和平路口', 30)]:4.125770
# y[('林德官(三和市場)', 43),('和平路口', 44)]:4.244382
# y[('和平路口', 18),('五權國小(三多二路)', 19)]:3.231997
# y[('和平路口', 30),('五權國小(三多二路)', 31)]:4.268643
# y[('和平路口', 44),('五權國小(三多二路)', 45)]:4.020994
# y[('五權國小(三多二路)', 45),('凱旋二路口', 45)]:4.020994
# y[('五權國小(三多二路)', 19),('凱旋二路口', 19)]:3.286995
# y[('五權國小(三多二路)', 31),('凱旋二路口', 31)]:4.206359
# y[('凱旋二路口', 19),('國際商工', 20)]:3.130472
# y[('凱旋二路口', 31),('國際商工', 32)]:4.006056
# y[('國際商工', 20),('三信家商', 21)]:3.098978
# y[('國際商工', 32),('三信家商', 33)]:3.942822
# y[('三信家商', 21),('五塊厝(三多一路)', 22)]:3.180709
# y[('三信家商', 33),('五塊厝(三多一路)', 34)]:3.962420
# y[('五塊厝(三多一路)', 22),('輔仁路口(三多一路)', 23)]:3.097429
# y[('五塊厝(三多一路)', 34),('輔仁路口(三多一路)', 35)]:3.821404
# y[('輔仁路口(三多一路)', 23),('中正體育場', 24)]:3.084022
# y[('輔仁路口(三多一路)', 35),('中正體育場', 36)]:3.721898
# y[('中正體育場', 24),('衛武營', 25)]:3.079547
# y[('中正體育場', 36),('衛武營', 37)]:3.661795
# y[('衛武營', 25),('衛武營國家藝術文化中心', 26)]:2.965490
# y[('衛武營', 37),('衛武營國家藝術文化中心', 38)]:3.526173
# y[('衛武營國家藝術文化中心', 26),('衛武社區', 29)]:3.108514
# y[('衛武營國家藝術文化中心', 38),('衛武社區', 41)]:3.565561
# y[('衛武營國家藝術文化中心', 43),dummy]:0.202489
# y[('衛武營國家藝術文化中心', 44),dummy]:0.066667
# y[('衛武社區', 29),('鳳山行政中心(澄清路)', 31)]:3.155070
# y[('衛武社區', 41),('鳳山行政中心(澄清路)', 43)]:3.540786
# y[('衛武社區', 44),dummy]:0.078067
# y[('鳳山行政中心(澄清路)', 31),('覺民路口(澄清路)', 33)]:3.151475
# y[('鳳山行政中心(澄清路)', 43),('覺民路口(澄清路)', 45)]:3.543881
# y[('覺民路口(澄清路)', 45),dummy]:3.543881
# y[('鳳山行政中心(澄清路)', 44),dummy]:0.031111
# y[('覺民路口(澄清路)', 33),('褒揚街口', 34)]:3.049814
# y[('褒揚街口', 34),('澄清路', 36)]:2.954507
# y[('澄清路', 36),('大華村', 37)]:2.906764
# y[('大華村', 37),('正修科大(澄清湖)', 39)]:2.821271
# y[('正修科大(澄清湖)', 39),('長庚復健大樓', 45)]:2.740664
# y[('長庚復健大樓', 45),dummy]:2.740664
# y[('長庚復健大樓', 44),dummy]:0.248807
# y[source,('前鎮站', 1)]:0.200000
# y[source,('前鎮站', 2)]:0.400000
# y[('前鎮站', 2),sink]:0.057143
# y[source,('前鎮站', 3)]:0.600000
# y[('前鎮站', 3),sink]:0.134694
# y[source,('前鎮站', 4)]:0.800000
# y[('前鎮站', 4),sink]:0.229738
# y[source,('前鎮站', 5)]:1.000000
# y[('前鎮站', 5),sink]:0.339775
# y[source,('前鎮站', 6)]:1.200000
# y[('前鎮站', 6),sink]:0.462664
# y[source,('前鎮站', 7)]:1.400000
# y[('前鎮站', 7),sink]:0.596569
# y[source,('前鎮站', 8)]:1.600000
# y[('前鎮站', 8),sink]:0.739917
# y[source,('前鎮站', 9)]:1.800000
# y[('前鎮站', 9),sink]:0.891357
# y[source,('前鎮站', 10)]:2.000000
# y[('前鎮站', 10),sink]:1.049735
# y[source,('前鎮站', 11)]:2.200000
# y[('前鎮站', 11),sink]:1.214058
# y[source,('前鎮站', 12)]:2.400000
# y[('前鎮站', 12),sink]:1.383479
# y[source,('前鎮站', 13)]:2.600000
# y[source,('前鎮站', 14)]:2.800000
# y[('前鎮站', 14),sink]:0.400000
# y[('前鎮站', 15),sink]:0.342857
# y[source,('前鎮站', 16)]:0.200000
# y[('前鎮站', 16),sink]:0.322449
# y[source,('前鎮站', 17)]:0.400000
# y[('前鎮站', 17),sink]:0.333528
# y[source,('前鎮站', 18)]:0.600000
# y[('前鎮站', 18),sink]:0.371595
# y[source,('前鎮站', 19)]:0.800000
# y[('前鎮站', 19),sink]:0.432796
# y[source,('前鎮站', 20)]:1.000000
# y[('前鎮站', 20),sink]:0.513825
# y[source,('前鎮站', 21)]:1.200000
# y[('前鎮站', 21),sink]:0.611850
# y[source,('前鎮站', 22)]:1.400000
# y[('前鎮站', 22),sink]:0.724443
# y[source,('前鎮站', 23)]:1.600000
# y[('前鎮站', 23),sink]:0.849522
# y[source,('前鎮站', 24)]:1.800000
# y[('前鎮站', 24),sink]:0.985305
# y[source,('前鎮站', 25)]:2.000000
# y[('前鎮站', 25),sink]:1.130261
# y[source,('前鎮站', 26)]:2.200000
# y[('前鎮站', 26),sink]:1.283081
# y[source,('前鎮站', 27)]:2.400000
# y[source,('前鎮站', 28)]:2.600000
# y[('前鎮站', 28),sink]:0.371429
# y[source,('前鎮站', 29)]:2.800000
# y[('前鎮站', 29),sink]:0.718367
# y[('前鎮站', 30),sink]:0.615743
# y[source,('前鎮站', 31)]:0.200000
# y[('前鎮站', 31),sink]:0.556352
# y[source,('前鎮站', 32)]:0.400000
# y[('前鎮站', 32),sink]:0.534016
# y[source,('前鎮站', 33)]:0.600000
# y[('前鎮站', 33),sink]:0.543442
# y[source,('前鎮站', 34)]:0.800000
# y[('前鎮站', 34),sink]:0.580093
# y[source,('前鎮站', 35)]:1.000000
# y[('前鎮站', 35),sink]:0.640080
# y[source,('前鎮站', 36)]:1.200000
# y[('前鎮站', 36),sink]:0.720068
# y[source,('前鎮站', 37)]:1.400000
# y[('前鎮站', 37),sink]:0.817201
# y[source,('前鎮站', 38)]:1.600000
# y[('前鎮站', 38),sink]:0.929030
# y[source,('前鎮站', 39)]:1.800000
# y[('前鎮站', 39),sink]:1.053454
# y[source,('前鎮站', 40)]:2.000000
# y[('前鎮站', 40),sink]:1.188675
# y[source,('前鎮站', 41)]:2.200000
# y[('前鎮站', 41),sink]:1.333150
# y[source,('前鎮站', 42)]:2.400000
# y[('前鎮站', 42),sink]:1.485557
# y[source,('前鎮站', 43)]:2.600000
# y[('前鎮站', 43),sink]:1.644763
# y[source,('前鎮站', 44)]:2.800000
# y[('前鎮站', 44),sink]:12.668580
# y[source,('輕軌經貿園區站', 31)]:0.066667
# y[source,('輕軌經貿園區站', 32)]:0.133333
# y[('輕軌經貿園區站', 32),sink]:0.027211
# y[source,('輕軌經貿園區站', 33)]:0.200000
# y[('輕軌經貿園區站', 33),sink]:0.051895
# y[source,('輕軌經貿園區站', 34)]:0.266667
# y[('輕軌經貿園區站', 34),sink]:0.082577
# y[source,('輕軌經貿園區站', 35)]:0.333333
# y[('輕軌經貿園區站', 35),sink]:0.118399
# y[source,('輕軌經貿園區站', 36)]:0.400000
# y[('輕軌經貿園區站', 36),sink]:0.158628
# y[source,('輕軌經貿園區站', 37)]:0.466667
# y[('輕軌經貿園區站', 37),sink]:0.202633
# y[source,('輕軌經貿園區站', 38)]:0.533333
# y[('輕軌經貿園區站', 38),sink]:0.249876
# y[source,('輕軌經貿園區站', 39)]:0.600000
# y[('輕軌經貿園區站', 39),sink]:0.299894
# y[source,('輕軌經貿園區站', 40)]:0.666667
# y[('輕軌經貿園區站', 40),sink]:0.352290
# y[source,('輕軌經貿園區站', 41)]:0.733333
# y[('輕軌經貿園區站', 41),sink]:0.406725
# y[source,('輕軌經貿園區站', 42)]:0.800000
# y[('輕軌經貿園區站', 42),sink]:0.462907
# y[source,('輕軌經貿園區站', 43)]:0.866667
# y[('輕軌經貿園區站', 43),sink]:0.520587
# y[source,('輕軌經貿園區站', 44)]:0.933333
# y[('輕軌經貿園區站', 44),sink]:4.056855
# y[source,('正勤路', 1)]:0.133333
# y[('正勤路', 1),sink]:0.019048
# y[source,('正勤路', 2)]:0.266667
# y[('正勤路', 2),sink]:0.054422
# y[source,('正勤路', 3)]:0.400000
# y[('正勤路', 3),sink]:0.103790
# y[source,('正勤路', 4)]:0.533333
# y[source,('正勤路', 5)]:0.666667
# y[('正勤路', 5),sink]:0.095238
# y[source,('正勤路', 6)]:0.800000
# y[('正勤路', 6),sink]:0.195918
# y[source,('正勤路', 7)]:0.933333
# y[('正勤路', 7),sink]:0.301263
# y[source,('正勤路', 8)]:1.066667
# y[('正勤路', 8),sink]:0.410607
# y[source,('正勤路', 9)]:1.200000
# y[('正勤路', 9),sink]:0.523377
# y[source,('正勤路', 10)]:1.333333
# y[('正勤路', 10),sink]:0.639085
# y[source,('正勤路', 11)]:1.466667
# y[('正勤路', 11),sink]:0.757311
# y[source,('正勤路', 12)]:1.600000
# y[('正勤路', 12),sink]:0.877695
# y[source,('正勤路', 13)]:1.733333
# y[('正勤路', 13),sink]:0.999929
# y[source,('正勤路', 14)]:1.866667
# y[('正勤路', 14),sink]:1.123749
# y[('正勤路', 15),sink]:0.963213
# y[source,('正勤路', 16)]:0.066667
# y[source,('正勤路', 17)]:0.133333
# y[('正勤路', 17),sink]:0.019048
# y[source,('正勤路', 18)]:0.200000
# y[('正勤路', 18),sink]:0.044898
# y[source,('正勤路', 19)]:0.266667
# y[('正勤路', 19),sink]:0.076579
# y[source,('正勤路', 20)]:0.333333
# y[('正勤路', 20),sink]:0.113258
# y[source,('正勤路', 21)]:0.400000
# y[('正勤路', 21),sink]:0.154221
# y[source,('正勤路', 22)]:0.466667
# y[('正勤路', 22),sink]:0.198856
# y[source,('正勤路', 23)]:0.533333
# y[('正勤路', 23),sink]:0.246639
# y[source,('正勤路', 24)]:0.600000
# y[('正勤路', 24),sink]:0.297119
# y[source,('正勤路', 25)]:0.666667
# y[('正勤路', 25),sink]:0.349912
# y[source,('正勤路', 26)]:0.733333
# y[('正勤路', 26),sink]:0.404686
# y[source,('正勤路', 27)]:0.800000
# y[('正勤路', 27),sink]:0.461160
# y[source,('正勤路', 28)]:0.866667
# y[('正勤路', 28),sink]:0.519089
# y[source,('正勤路', 29)]:0.933333
# y[('正勤路', 29),sink]:0.578267
# y[source,('正勤路', 31)]:0.066667
# y[source,('正勤路', 32)]:0.133333
# y[('正勤路', 32),sink]:0.027211
# y[source,('正勤路', 33)]:0.200000
# y[('正勤路', 33),sink]:0.051895
# y[source,('正勤路', 34)]:0.266667
# y[('正勤路', 34),sink]:0.082577
# y[source,('正勤路', 35)]:0.333333
# y[('正勤路', 35),sink]:0.118399
# y[source,('正勤路', 36)]:0.400000
# y[('正勤路', 36),sink]:0.158628
# y[source,('正勤路', 37)]:0.466667
# y[('正勤路', 37),sink]:0.202633
# y[source,('正勤路', 38)]:0.533333
# y[('正勤路', 38),sink]:0.249876
# y[source,('正勤路', 39)]:0.600000
# y[('正勤路', 39),sink]:0.299894
# y[source,('正勤路', 40)]:0.666667
# y[('正勤路', 40),sink]:0.352290
# y[source,('正勤路', 41)]:0.733333
# y[('正勤路', 41),sink]:0.406725
# y[source,('正勤路', 42)]:0.800000
# y[('正勤路', 42),sink]:0.462907
# y[source,('正勤路', 43)]:0.866667
# y[('正勤路', 43),sink]:0.520587
# y[source,('正勤路', 44)]:0.933333
# y[('正勤路', 44),sink]:4.056855
# y[source,('正勤社區', 1)]:0.133333
# y[('正勤社區', 1),sink]:0.019048
# y[source,('正勤社區', 2)]:0.266667
# y[('正勤社區', 2),sink]:0.054422
# y[source,('正勤社區', 3)]:0.400000
# y[('正勤社區', 3),sink]:0.103790
# y[source,('正勤社區', 4)]:0.533333
# y[('正勤社區', 4),sink]:0.165153
# y[source,('正勤社區', 5)]:0.666667
# y[source,('正勤社區', 6)]:0.800000
# y[('正勤社區', 6),sink]:0.114286
# y[source,('正勤社區', 7)]:0.933333
# y[('正勤社區', 7),sink]:0.231293
# y[source,('正勤社區', 8)]:1.066667
# y[('正勤社區', 8),sink]:0.350632
# y[source,('正勤社區', 9)]:1.200000
# y[('正勤社區', 9),sink]:0.471970
# y[source,('正勤社區', 10)]:1.333333
# y[('正勤社區', 10),sink]:0.595022
# y[source,('正勤社區', 11)]:1.466667
# y[('正勤社區', 11),sink]:0.719543
# y[source,('正勤社區', 12)]:1.600000
# y[('正勤社區', 12),sink]:0.845322
# y[source,('正勤社區', 13)]:1.733333
# y[('正勤社區', 13),sink]:0.972181
# y[source,('正勤社區', 14)]:1.866667
# y[('正勤社區', 14),sink]:1.099965
# y[('正勤社區', 15),sink]:0.942827
# y[source,('正勤社區', 16)]:0.133333
# y[('正勤社區', 16),sink]:0.827185
# y[source,('正勤社區', 17)]:0.266667
# y[source,('正勤社區', 18)]:0.400000
# y[('正勤社區', 18),sink]:0.057143
# y[source,('正勤社區', 19)]:0.533333
# y[('正勤社區', 19),sink]:0.125170
# y[source,('正勤社區', 20)]:0.666667
# y[('正勤社區', 20),sink]:0.202527
# y[source,('正勤社區', 21)]:0.800000
# y[('正勤社區', 21),sink]:0.287880
# y[source,('正勤社區', 22)]:0.933333
# y[('正勤社區', 22),sink]:0.380088
# y[source,('正勤社區', 23)]:1.066667
# y[('正勤社區', 23),sink]:0.478170
# y[source,('正勤社區', 24)]:1.200000
# y[('正勤社區', 24),sink]:0.581289
# y[source,('正勤社區', 25)]:1.333333
# y[('正勤社區', 25),sink]:0.688724
# y[source,('正勤社區', 26)]:1.466667
# y[('正勤社區', 26),sink]:0.799859
# y[source,('正勤社區', 27)]:1.600000
# y[('正勤社區', 27),sink]:0.914164
# y[source,('正勤社區', 28)]:1.733333
# y[('正勤社區', 28),sink]:1.031189
# y[source,('正勤社區', 29)]:1.866667
# y[('正勤社區', 29),sink]:1.150543
# y[('正勤社區', 30),sink]:0.986179
# y[source,('正勤社區', 31)]:0.066667
# y[source,('正勤社區', 32)]:0.133333
# y[('正勤社區', 32),sink]:0.019048
# y[source,('正勤社區', 33)]:0.200000
# y[('正勤社區', 33),sink]:0.044898
# y[source,('正勤社區', 34)]:0.266667
# y[('正勤社區', 34),sink]:0.076579
# y[source,('正勤社區', 35)]:0.333333
# y[('正勤社區', 35),sink]:0.113258
# y[source,('正勤社區', 36)]:0.400000
# y[('正勤社區', 36),sink]:0.154221
# y[source,('正勤社區', 37)]:0.466667
# y[('正勤社區', 37),sink]:0.198856
# y[source,('正勤社區', 38)]:0.533333
# y[('正勤社區', 38),sink]:0.246639
# y[source,('正勤社區', 39)]:0.600000
# y[('正勤社區', 39),sink]:0.297119
# y[source,('正勤社區', 40)]:0.666667
# y[('正勤社區', 40),sink]:0.349912
# y[source,('正勤社區', 41)]:0.733333
# y[('正勤社區', 41),sink]:0.404686
# y[source,('正勤社區', 42)]:0.800000
# y[('正勤社區', 42),sink]:0.461160
# y[source,('正勤社區', 43)]:0.866667
# y[('正勤社區', 43),sink]:0.519089
# y[source,('正勤社區', 44)]:0.933333
# y[('正勤社區', 44),sink]:4.047868
# y[source,('中華五路', 16)]:0.066667
# y[source,('中華五路', 17)]:0.133333
# y[('中華五路', 17),sink]:0.027211
# y[source,('中華五路', 18)]:0.200000
# y[('中華五路', 18),sink]:0.051895
# y[source,('中華五路', 19)]:0.266667
# y[source,('中華五路', 20)]:0.333333
# y[('中華五路', 20),sink]:0.047619
# y[source,('中華五路', 21)]:0.400000
# y[('中華五路', 21),sink]:0.097959
# y[source,('中華五路', 22)]:0.466667
# y[('中華五路', 22),sink]:0.150632
# y[source,('中華五路', 23)]:0.533333
# y[('中華五路', 23),sink]:0.205303
# y[source,('中華五路', 24)]:0.600000
# y[('中華五路', 24),sink]:0.261689
# y[source,('中華五路', 25)]:0.666667
# y[('中華五路', 25),sink]:0.319543
# y[source,('中華五路', 26)]:0.733333
# y[('中華五路', 26),sink]:0.378656
# y[source,('中華五路', 27)]:0.800000
# y[('中華五路', 27),sink]:0.438848
# y[source,('中華五路', 28)]:0.866667
# y[('中華五路', 28),sink]:0.499965
# y[source,('中華五路', 29)]:0.933333
# y[('中華五路', 29),sink]:0.561874
# y[('中華五路', 30),sink]:0.481607
# y[('中華五路', 31),sink]:0.412806
# y[('中華五路', 32),sink]:0.353833
# y[source,('新光路口(圖書總館)', 1)]:0.066667
# y[source,('新光路口(圖書總館)', 2)]:0.133333
# y[('新光路口(圖書總館)', 2),sink]:0.027211
# y[source,('新光路口(圖書總館)', 3)]:0.200000
# y[('新光路口(圖書總館)', 3),sink]:0.051895
# y[source,('新光路口(圖書總館)', 4)]:0.266667
# y[('新光路口(圖書總館)', 4),sink]:0.082577
# y[source,('新光路口(圖書總館)', 5)]:0.333333
# y[('新光路口(圖書總館)', 5),sink]:0.118399
# y[source,('新光路口(圖書總館)', 6)]:0.400000
# y[('新光路口(圖書總館)', 6),sink]:0.158628
# y[source,('新光路口(圖書總館)', 7)]:0.466667
# y[('新光路口(圖書總館)', 7),sink]:0.202633
# y[source,('新光路口(圖書總館)', 8)]:0.533333
# y[source,('新光路口(圖書總館)', 9)]:0.600000
# y[('新光路口(圖書總館)', 9),sink]:0.085714
# y[source,('新光路口(圖書總館)', 10)]:0.666667
# y[('新光路口(圖書總館)', 10),sink]:0.168707
# y[source,('新光路口(圖書總館)', 11)]:0.733333
# y[('新光路口(圖書總館)', 11),sink]:0.249368
# y[source,('新光路口(圖書總館)', 12)]:0.800000
# y[('新光路口(圖書總館)', 12),sink]:0.328030
# y[source,('新光路口(圖書總館)', 13)]:0.866667
# y[('新光路口(圖書總館)', 13),sink]:0.404978
# y[source,('新光路口(圖書總館)', 14)]:0.933333
# y[('新光路口(圖書總館)', 14),sink]:0.480457
# y[('新光路口(圖書總館)', 15),sink]:0.411821
# y[source,('新光路口(圖書總館)', 16)]:0.066667
# y[('新光路口(圖書總館)', 16),sink]:0.362513
# y[source,('新光路口(圖書總館)', 17)]:0.133333
# y[('新光路口(圖書總館)', 17),sink]:0.329773
# y[source,('新光路口(圖書總館)', 18)]:0.200000
# y[('新光路口(圖書總館)', 18),sink]:0.311234
# y[source,('新光路口(圖書總館)', 19)]:0.266667
# y[('新光路口(圖書總館)', 19),sink]:0.304867
# y[source,('新光路口(圖書總館)', 20)]:0.333333
# y[source,('新光路口(圖書總館)', 21)]:0.400000
# y[('新光路口(圖書總館)', 21),sink]:0.057143
# y[source,('新光路口(圖書總館)', 22)]:0.466667
# y[('新光路口(圖書總館)', 22),sink]:0.115646
# y[source,('新光路口(圖書總館)', 23)]:0.533333
# y[('新光路口(圖書總館)', 23),sink]:0.175316
# y[source,('新光路口(圖書總館)', 24)]:0.600000
# y[('新光路口(圖書總館)', 24),sink]:0.235985
# y[source,('新光路口(圖書總館)', 25)]:0.666667
# y[('新光路口(圖書總館)', 25),sink]:0.297511
# y[source,('新光路口(圖書總館)', 26)]:0.733333
# y[('新光路口(圖書總館)', 26),sink]:0.359771
# y[source,('新光路口(圖書總館)', 27)]:0.800000
# y[('新光路口(圖書總館)', 27),sink]:0.422661
# y[source,('新光路口(圖書總館)', 28)]:0.866667
# y[('新光路口(圖書總館)', 28),sink]:0.486090
# y[source,('新光路口(圖書總館)', 29)]:0.933333
# y[('新光路口(圖書總館)', 29),sink]:0.549982
# y[('新光路口(圖書總館)', 30),sink]:0.471413
# y[('新光路口(圖書總館)', 31),sink]:0.404069
# y[('新光路口(圖書總館)', 32),sink]:0.346345
# y[('新光路口(圖書總館)', 33),sink]:0.296867
# y[source,('三多四路口', 1)]:0.066667
# y[source,('三多四路口', 2)]:0.133333
# y[('三多四路口', 2),sink]:0.027211
# y[source,('三多四路口', 3)]:0.200000
# y[('三多四路口', 3),sink]:0.051895
# y[source,('三多四路口', 4)]:0.266667
# y[('三多四路口', 4),sink]:0.082577
# y[source,('三多四路口', 5)]:0.333333
# y[('三多四路口', 5),sink]:0.118399
# y[source,('三多四路口', 6)]:0.400000
# y[('三多四路口', 6),sink]:0.158628
# y[source,('三多四路口', 7)]:0.466667
# y[('三多四路口', 7),sink]:0.202633
# y[source,('三多四路口', 8)]:0.533333
# y[('三多四路口', 8),sink]:0.249876
# y[source,('三多四路口', 9)]:0.600000
# y[source,('三多四路口', 10)]:0.666667
# y[('三多四路口', 10),sink]:0.095238
# y[source,('三多四路口', 11)]:0.733333
# y[('三多四路口', 11),sink]:0.186395
# y[source,('三多四路口', 12)]:0.800000
# y[('三多四路口', 12),sink]:0.274052
# y[source,('三多四路口', 13)]:0.866667
# y[('三多四路口', 13),sink]:0.358712
# y[source,('三多四路口', 14)]:0.933333
# y[('三多四路口', 14),sink]:0.440800
# y[('三多四路口', 15),sink]:0.377829
# y[('三多四路口', 16),sink]:0.323853
# y[('三多四路口', 17),sink]:0.277589
# y[('三多四路口', 18),sink]:0.237933
# y[('三多四路口', 19),sink]:0.203943
# y[('三多四路口', 20),sink]:0.174808
# y[source,('大遠百百貨(捷運三多商圈站)', 1)]:0.133333
# y[('大遠百百貨(捷運三多商圈站)', 1),sink]:0.019048
# y[source,('大遠百百貨(捷運三多商圈站)', 2)]:0.266667
# y[('大遠百百貨(捷運三多商圈站)', 2),sink]:0.054422
# y[source,('大遠百百貨(捷運三多商圈站)', 3)]:0.400000
# y[('大遠百百貨(捷運三多商圈站)', 3),sink]:0.103790
# y[source,('大遠百百貨(捷運三多商圈站)', 4)]:0.533333
# y[('大遠百百貨(捷運三多商圈站)', 4),sink]:0.165153
# y[source,('大遠百百貨(捷運三多商圈站)', 5)]:0.666667
# y[('大遠百百貨(捷運三多商圈站)', 5),sink]:0.236798
# y[source,('大遠百百貨(捷運三多商圈站)', 6)]:0.800000
# y[('大遠百百貨(捷運三多商圈站)', 6),sink]:0.317256
# y[source,('大遠百百貨(捷運三多商圈站)', 7)]:0.933333
# y[('大遠百百貨(捷運三多商圈站)', 7),sink]:0.405267
# y[source,('大遠百百貨(捷運三多商圈站)', 8)]:1.066667
# y[('大遠百百貨(捷運三多商圈站)', 8),sink]:0.499752
# y[source,('大遠百百貨(捷運三多商圈站)', 9)]:1.200000
# y[('大遠百百貨(捷運三多商圈站)', 9),sink]:0.599788
# y[source,('大遠百百貨(捷運三多商圈站)', 10)]:1.333333
# y[('大遠百百貨(捷運三多商圈站)', 10),sink]:0.704580
# y[source,('大遠百百貨(捷運三多商圈站)', 11)]:1.466667
# y[source,('大遠百百貨(捷運三多商圈站)', 12)]:1.600000
# y[('大遠百百貨(捷運三多商圈站)', 12),sink]:0.228571
# y[source,('大遠百百貨(捷運三多商圈站)', 13)]:1.733333
# y[('大遠百百貨(捷運三多商圈站)', 13),sink]:0.443537
# y[source,('大遠百百貨(捷運三多商圈站)', 14)]:1.866667
# y[('大遠百百貨(捷運三多商圈站)', 14),sink]:0.646842
# y[('大遠百百貨(捷運三多商圈站)', 15),sink]:0.554436
# y[source,('大遠百百貨(捷運三多商圈站)', 16)]:0.266667
# y[('大遠百百貨(捷運三多商圈站)', 16),sink]:0.513326
# y[source,('大遠百百貨(捷運三多商圈站)', 17)]:0.533333
# y[('大遠百百貨(捷運三多商圈站)', 17),sink]:0.516184
# y[source,('大遠百百貨(捷運三多商圈站)', 18)]:0.800000
# y[('大遠百百貨(捷運三多商圈站)', 18),sink]:0.556729
# y[source,('大遠百百貨(捷運三多商圈站)', 19)]:1.066667
# y[('大遠百百貨(捷運三多商圈站)', 19),sink]:0.629577
# y[source,('大遠百百貨(捷運三多商圈站)', 20)]:1.333333
# y[('大遠百百貨(捷運三多商圈站)', 20),sink]:0.730114
# y[source,('大遠百百貨(捷運三多商圈站)', 21)]:1.600000
# y[('大遠百百貨(捷運三多商圈站)', 21),sink]:0.854383
# y[source,('大遠百百貨(捷運三多商圈站)', 22)]:1.866667
# y[('大遠百百貨(捷運三多商圈站)', 22),sink]:0.998995
# y[source,('大遠百百貨(捷運三多商圈站)', 23)]:2.133333
# y[source,('大遠百百貨(捷運三多商圈站)', 24)]:2.400000
# y[('大遠百百貨(捷運三多商圈站)', 24),sink]:0.342857
# y[source,('大遠百百貨(捷運三多商圈站)', 25)]:2.666667
# y[('大遠百百貨(捷運三多商圈站)', 25),sink]:0.674830
# y[source,('大遠百百貨(捷運三多商圈站)', 26)]:2.933333
# y[('大遠百百貨(捷運三多商圈站)', 26),sink]:0.997473
# y[source,('大遠百百貨(捷運三多商圈站)', 27)]:3.200000
# y[('大遠百百貨(捷運三多商圈站)', 27),sink]:1.312120
# y[source,('大遠百百貨(捷運三多商圈站)', 28)]:3.466667
# y[('大遠百百貨(捷運三多商圈站)', 28),sink]:1.619912
# y[source,('大遠百百貨(捷運三多商圈站)', 29)]:3.733333
# y[('大遠百百貨(捷運三多商圈站)', 29),sink]:1.921830
# y[('大遠百百貨(捷運三多商圈站)', 30),sink]:1.647283
# y[source,('大遠百百貨(捷運三多商圈站)', 31)]:0.200000
# y[('大遠百百貨(捷運三多商圈站)', 31),sink]:1.440528
# y[source,('大遠百百貨(捷運三多商圈站)', 32)]:0.400000
# y[('大遠百百貨(捷運三多商圈站)', 32),sink]:1.291881
# y[source,('大遠百百貨(捷運三多商圈站)', 33)]:0.600000
# y[('大遠百百貨(捷運三多商圈站)', 33),sink]:1.193041
# y[source,('大遠百百貨(捷運三多商圈站)', 34)]:0.800000
# y[('大遠百百貨(捷運三多商圈站)', 34),sink]:1.136892
# y[source,('大遠百百貨(捷運三多商圈站)', 35)]:1.000000
# y[('大遠百百貨(捷運三多商圈站)', 35),sink]:1.117336
# y[source,('大遠百百貨(捷運三多商圈站)', 36)]:1.200000
# y[('大遠百百貨(捷運三多商圈站)', 36),sink]:1.129145
# y[source,('大遠百百貨(捷運三多商圈站)', 37)]:1.400000
# y[source,('大遠百百貨(捷運三多商圈站)', 38)]:1.600000
# y[('大遠百百貨(捷運三多商圈站)', 38),sink]:0.228571
# y[source,('大遠百百貨(捷運三多商圈站)', 39)]:1.800000
# y[('大遠百百貨(捷運三多商圈站)', 39),sink]:0.453061
# y[source,('大遠百百貨(捷運三多商圈站)', 40)]:2.000000
# y[('大遠百百貨(捷運三多商圈站)', 40),sink]:0.674052
# y[source,('大遠百百貨(捷運三多商圈站)', 41)]:2.200000
# y[('大遠百百貨(捷運三多商圈站)', 41),sink]:0.892045
# y[source,('大遠百百貨(捷運三多商圈站)', 42)]:2.400000
# y[('大遠百百貨(捷運三多商圈站)', 42),sink]:1.107467
# y[source,('大遠百百貨(捷運三多商圈站)', 43)]:2.600000
# y[('大遠百百貨(捷運三多商圈站)', 43),sink]:1.320686
# y[source,('大遠百百貨(捷運三多商圈站)', 44)]:2.800000
# y[('大遠百百貨(捷運三多商圈站)', 44),sink]:10.724117
# y[source,('新光三越(捷運三多商圈站)', 1)]:0.266667
# y[('新光三越(捷運三多商圈站)', 1),sink]:0.038095
# y[source,('新光三越(捷運三多商圈站)', 2)]:0.533333
# y[('新光三越(捷運三多商圈站)', 2),sink]:0.108844
# y[source,('新光三越(捷運三多商圈站)', 3)]:0.800000
# y[('新光三越(捷運三多商圈站)', 3),sink]:0.207580
# y[source,('新光三越(捷運三多商圈站)', 4)]:1.066667
# y[('新光三越(捷運三多商圈站)', 4),sink]:0.330307
# y[source,('新光三越(捷運三多商圈站)', 5)]:1.333333
# y[('新光三越(捷運三多商圈站)', 5),sink]:0.473596
# y[source,('新光三越(捷運三多商圈站)', 6)]:1.600000
# y[('新光三越(捷運三多商圈站)', 6),sink]:0.634511
# y[source,('新光三越(捷運三多商圈站)', 7)]:1.866667
# y[('新光三越(捷運三多商圈站)', 7),sink]:0.810533
# y[source,('新光三越(捷運三多商圈站)', 8)]:2.133333
# y[('新光三越(捷運三多商圈站)', 8),sink]:0.999505
# y[source,('新光三越(捷運三多商圈站)', 9)]:2.400000
# y[('新光三越(捷運三多商圈站)', 9),sink]:1.199576
# y[source,('新光三越(捷運三多商圈站)', 10)]:2.666667
# y[('新光三越(捷運三多商圈站)', 10),sink]:1.409160
# y[source,('新光三越(捷運三多商圈站)', 11)]:2.933333
# y[('新光三越(捷運三多商圈站)', 11),sink]:1.626899
# y[source,('新光三越(捷運三多商圈站)', 12)]:3.200000
# y[source,('新光三越(捷運三多商圈站)', 13)]:3.466667
# y[('新光三越(捷運三多商圈站)', 13),sink]:0.495238
# y[source,('新光三越(捷運三多商圈站)', 14)]:3.733333
# y[('新光三越(捷運三多商圈站)', 14),sink]:0.957823
# y[('新光三越(捷運三多商圈站)', 15),sink]:0.820991
# y[source,('新光三越(捷運三多商圈站)', 16)]:0.133333
# y[('新光三越(捷運三多商圈站)', 16),sink]:0.722754
# y[source,('新光三越(捷運三多商圈站)', 17)]:0.266667
# y[('新光三越(捷運三多商圈站)', 17),sink]:0.657599
# y[source,('新光三越(捷運三多商圈站)', 18)]:0.400000
# y[('新光三越(捷運三多商圈站)', 18),sink]:0.620799
# y[source,('新光三越(捷運三多商圈站)', 19)]:0.533333
# y[('新光三越(捷運三多商圈站)', 19),sink]:0.608304
# y[source,('新光三越(捷運三多商圈站)', 20)]:0.666667
# y[('新光三越(捷運三多商圈站)', 20),sink]:0.616642
# y[source,('新光三越(捷運三多商圈站)', 21)]:0.800000
# y[('新光三越(捷運三多商圈站)', 21),sink]:0.642836
# y[source,('新光三越(捷運三多商圈站)', 22)]:0.933333
# y[('新光三越(捷運三多商圈站)', 22),sink]:0.684335
# y[source,('新光三越(捷運三多商圈站)', 23)]:1.066667
# y[('新光三越(捷運三多商圈站)', 23),sink]:0.738954
# y[source,('新光三越(捷運三多商圈站)', 24)]:1.200000
# y[source,('新光三越(捷運三多商圈站)', 25)]:1.333333
# y[('新光三越(捷運三多商圈站)', 25),sink]:0.190476
# y[source,('新光三越(捷運三多商圈站)', 26)]:1.466667
# y[('新光三越(捷運三多商圈站)', 26),sink]:0.372789
# y[source,('新光三越(捷運三多商圈站)', 27)]:1.600000
# y[('新光三越(捷運三多商圈站)', 27),sink]:0.548105
# y[source,('新光三越(捷運三多商圈站)', 28)]:1.733333
# y[('新光三越(捷運三多商圈站)', 28),sink]:0.717423
# y[source,('新光三越(捷運三多商圈站)', 29)]:1.866667
# y[('新光三越(捷運三多商圈站)', 29),sink]:0.881601
# y[('新光三越(捷運三多商圈站)', 30),sink]:0.755658
# y[source,('新光三越(捷運三多商圈站)', 31)]:0.200000
# y[('新光三越(捷運三多商圈站)', 31),sink]:0.676278
# y[source,('新光三越(捷運三多商圈站)', 32)]:0.400000
# y[('新光三越(捷運三多商圈站)', 32),sink]:0.636810
# y[source,('新光三越(捷運三多商圈站)', 33)]:0.600000
# y[('新光三越(捷運三多商圈站)', 33),sink]:0.631551
# y[source,('新光三越(捷運三多商圈站)', 34)]:0.800000
# y[('新光三越(捷運三多商圈站)', 34),sink]:0.655615
# y[source,('新光三越(捷運三多商圈站)', 35)]:1.000000
# y[('新光三越(捷運三多商圈站)', 35),sink]:0.704813
# y[source,('新光三越(捷運三多商圈站)', 36)]:1.200000
# y[('新光三越(捷運三多商圈站)', 36),sink]:0.775554
# y[source,('新光三越(捷運三多商圈站)', 37)]:1.400000
# y[('新光三越(捷運三多商圈站)', 37),sink]:0.864761
# y[source,('新光三越(捷運三多商圈站)', 38)]:1.600000
# y[source,('新光三越(捷運三多商圈站)', 39)]:1.800000
# y[('新光三越(捷運三多商圈站)', 39),sink]:0.257143
# y[source,('新光三越(捷運三多商圈站)', 40)]:2.000000
# y[('新光三越(捷運三多商圈站)', 40),sink]:0.506122
# y[source,('新光三越(捷運三多商圈站)', 41)]:2.200000
# y[('新光三越(捷運三多商圈站)', 41),sink]:0.748105
# y[source,('新光三越(捷運三多商圈站)', 42)]:2.400000
# y[('新光三越(捷運三多商圈站)', 42),sink]:0.984090
# y[source,('新光三越(捷運三多商圈站)', 43)]:2.600000
# y[('新光三越(捷運三多商圈站)', 43),sink]:1.214934
# y[source,('新光三越(捷運三多商圈站)', 44)]:2.800000
# y[('新光三越(捷運三多商圈站)', 44),sink]:10.089606
# y[source,('三多三路', 1)]:0.133333
# y[('三多三路', 1),sink]:0.019048
# y[source,('三多三路', 2)]:0.266667
# y[('三多三路', 2),sink]:0.054422
# y[source,('三多三路', 3)]:0.400000
# y[('三多三路', 3),sink]:0.103790
# y[source,('三多三路', 4)]:0.533333
# y[('三多三路', 4),sink]:0.165153
# y[source,('三多三路', 5)]:0.666667
# y[('三多三路', 5),sink]:0.236798
# y[source,('三多三路', 6)]:0.800000
# y[('三多三路', 6),sink]:0.317256
# y[source,('三多三路', 7)]:0.933333
# y[('三多三路', 7),sink]:0.405267
# y[source,('三多三路', 8)]:1.066667
# y[('三多三路', 8),sink]:0.499752
# y[source,('三多三路', 9)]:1.200000
# y[('三多三路', 9),sink]:0.599788
# y[source,('三多三路', 10)]:1.333333
# y[('三多三路', 10),sink]:0.704580
# y[source,('三多三路', 11)]:1.466667
# y[('三多三路', 11),sink]:0.813450
# y[source,('三多三路', 12)]:1.600000
# y[('三多三路', 12),sink]:0.925814
# y[source,('三多三路', 13)]:1.733333
# y[source,('三多三路', 14)]:1.866667
# y[('三多三路', 14),sink]:0.266667
# y[('三多三路', 15),sink]:0.228571
# y[source,('三多三路', 16)]:0.133333
# y[('三多三路', 16),sink]:0.214966
# y[source,('三多三路', 17)]:0.266667
# y[('三多三路', 17),sink]:0.222352
# y[source,('三多三路', 18)]:0.400000
# y[('三多三路', 18),sink]:0.247730
# y[source,('三多三路', 19)]:0.533333
# y[('三多三路', 19),sink]:0.288531
# y[source,('三多三路', 20)]:0.666667
# y[('三多三路', 20),sink]:0.342550
# y[source,('三多三路', 21)]:0.800000
# y[('三多三路', 21),sink]:0.407900
# y[source,('三多三路', 22)]:0.933333
# y[('三多三路', 22),sink]:0.482962
# y[source,('三多三路', 23)]:1.066667
# y[('三多三路', 23),sink]:0.566348
# y[source,('三多三路', 24)]:1.200000
# y[('三多三路', 24),sink]:0.656870
# y[source,('三多三路', 25)]:1.333333
# y[source,('三多三路', 26)]:1.466667
# y[('三多三路', 26),sink]:0.209524
# y[source,('三多三路', 27)]:1.600000
# y[('三多三路', 27),sink]:0.408163
# y[source,('三多三路', 28)]:1.733333
# y[('三多三路', 28),sink]:0.597473
# y[source,('三多三路', 29)]:1.866667
# y[('三多三路', 29),sink]:0.778787
# y[('三多三路', 30),sink]:0.667531
# y[source,('三多三路', 31)]:0.133333
# y[('三多三路', 31),sink]:0.591217
# y[source,('三多三路', 32)]:0.266667
# y[('三多三路', 32),sink]:0.544853
# y[source,('三多三路', 33)]:0.400000
# y[('三多三路', 33),sink]:0.524160
# y[source,('三多三路', 34)]:0.533333
# y[('三多三路', 34),sink]:0.525470
# y[source,('三多三路', 35)]:0.666667
# y[('三多三路', 35),sink]:0.545641
# y[source,('三多三路', 36)]:0.800000
# y[('三多三路', 36),sink]:0.581978
# y[source,('三多三路', 37)]:0.933333
# y[('三多三路', 37),sink]:0.632172
# y[source,('三多三路', 38)]:1.066667
# y[('三多三路', 38),sink]:0.694242
# y[source,('三多三路', 39)]:1.200000
# y[source,('三多三路', 40)]:1.333333
# y[('三多三路', 40),sink]:0.190476
# y[source,('三多三路', 41)]:1.466667
# y[('三多三路', 41),sink]:0.372789
# y[source,('三多三路', 42)]:1.600000
# y[('三多三路', 42),sink]:0.548105
# y[source,('三多三路', 43)]:1.733333
# y[('三多三路', 43),sink]:0.717423
# y[source,('三多三路', 44)]:1.866667
# y[('三多三路', 44),sink]:6.171206
# y[source,('仁愛三街口', 1)]:0.133333
# y[('仁愛三街口', 1),sink]:0.019048
# y[source,('仁愛三街口', 2)]:0.266667
# y[('仁愛三街口', 2),sink]:0.054422
# y[source,('仁愛三街口', 3)]:0.400000
# y[('仁愛三街口', 3),sink]:0.103790
# y[source,('仁愛三街口', 4)]:0.533333
# y[('仁愛三街口', 4),sink]:0.165153
# y[source,('仁愛三街口', 5)]:0.666667
# y[('仁愛三街口', 5),sink]:0.236798
# y[source,('仁愛三街口', 6)]:0.800000
# y[('仁愛三街口', 6),sink]:0.317256
# y[source,('仁愛三街口', 7)]:0.933333
# y[('仁愛三街口', 7),sink]:0.405267
# y[source,('仁愛三街口', 8)]:1.066667
# y[('仁愛三街口', 8),sink]:0.499752
# y[source,('仁愛三街口', 9)]:1.200000
# y[('仁愛三街口', 9),sink]:0.599788
# y[source,('仁愛三街口', 10)]:1.333333
# y[('仁愛三街口', 10),sink]:0.704580
# y[source,('仁愛三街口', 11)]:1.466667
# y[('仁愛三街口', 11),sink]:0.813450
# y[source,('仁愛三街口', 12)]:1.600000
# y[('仁愛三街口', 12),sink]:0.925814
# y[source,('仁愛三街口', 13)]:1.733333
# y[('仁愛三街口', 13),sink]:1.041174
# y[source,('仁愛三街口', 14)]:1.866667
# y[source,('仁愛三街口', 16)]:0.066667
# y[source,('仁愛三街口', 17)]:0.133333
# y[('仁愛三街口', 17),sink]:0.027211
# y[source,('仁愛三街口', 18)]:0.200000
# y[('仁愛三街口', 18),sink]:0.051895
# y[source,('仁愛三街口', 19)]:0.266667
# y[('仁愛三街口', 19),sink]:0.082577
# y[source,('仁愛三街口', 20)]:0.333333
# y[('仁愛三街口', 20),sink]:0.118399
# y[source,('仁愛三街口', 21)]:0.400000
# y[('仁愛三街口', 21),sink]:0.158628
# y[source,('仁愛三街口', 22)]:0.466667
# y[('仁愛三街口', 22),sink]:0.202633
# y[source,('仁愛三街口', 23)]:0.533333
# y[('仁愛三街口', 23),sink]:0.249876
# y[source,('仁愛三街口', 24)]:0.600000
# y[('仁愛三街口', 24),sink]:0.299894
# y[source,('仁愛三街口', 25)]:0.666667
# y[('仁愛三街口', 25),sink]:0.352290
# y[source,('仁愛三街口', 26)]:0.733333
# y[source,('仁愛三街口', 27)]:0.800000
# y[('仁愛三街口', 27),sink]:0.114286
# y[source,('仁愛三街口', 28)]:0.866667
# y[('仁愛三街口', 28),sink]:0.221769
# y[source,('仁愛三街口', 29)]:0.933333
# y[('仁愛三街口', 29),sink]:0.323421
# y[('仁愛三街口', 30),sink]:0.277218
# y[source,('仁愛三街口', 31)]:0.133333
# y[('仁愛三街口', 31),sink]:0.256663
# y[source,('仁愛三街口', 32)]:0.266667
# y[('仁愛三街口', 32),sink]:0.258092
# y[source,('仁愛三街口', 33)]:0.400000
# y[('仁愛三街口', 33),sink]:0.278365
# y[source,('仁愛三街口', 34)]:0.533333
# y[('仁愛三街口', 34),sink]:0.314789
# y[source,('仁愛三街口', 35)]:0.666667
# y[('仁愛三街口', 35),sink]:0.365057
# y[source,('仁愛三街口', 36)]:0.800000
# y[('仁愛三街口', 36),sink]:0.427192
# y[source,('仁愛三街口', 37)]:0.933333
# y[('仁愛三街口', 37),sink]:0.499498
# y[source,('仁愛三街口', 38)]:1.066667
# y[('仁愛三街口', 38),sink]:0.580522
# y[source,('仁愛三街口', 39)]:1.200000
# y[('仁愛三街口', 39),sink]:0.669019
# y[source,('仁愛三街口', 40)]:1.333333
# y[source,('仁愛三街口', 41)]:1.466667
# y[('仁愛三街口', 41),sink]:0.209524
# y[source,('仁愛三街口', 42)]:1.600000
# y[('仁愛三街口', 42),sink]:0.408163
# y[source,('仁愛三街口', 43)]:1.733333
# y[('仁愛三街口', 43),sink]:0.597473
# y[source,('仁愛三街口', 44)]:1.866667
# y[('仁愛三街口', 44),sink]:5.451506
# y[source,('三多復興路口', 1)]:0.066667
# y[source,('三多復興路口', 2)]:0.133333
# y[('三多復興路口', 2),sink]:0.027211
# y[source,('三多復興路口', 3)]:0.200000
# y[('三多復興路口', 3),sink]:0.051895
# y[source,('三多復興路口', 4)]:0.266667
# y[('三多復興路口', 4),sink]:0.082577
# y[source,('三多復興路口', 5)]:0.333333
# y[('三多復興路口', 5),sink]:0.118399
# y[source,('三多復興路口', 6)]:0.400000
# y[('三多復興路口', 6),sink]:0.158628
# y[source,('三多復興路口', 7)]:0.466667
# y[('三多復興路口', 7),sink]:0.202633
# y[source,('三多復興路口', 8)]:0.533333
# y[('三多復興路口', 8),sink]:0.249876
# y[source,('三多復興路口', 9)]:0.600000
# y[('三多復興路口', 9),sink]:0.299894
# y[source,('三多復興路口', 10)]:0.666667
# y[('三多復興路口', 10),sink]:0.352290
# y[source,('三多復興路口', 11)]:0.733333
# y[('三多復興路口', 11),sink]:0.406725
# y[source,('三多復興路口', 12)]:0.800000
# y[('三多復興路口', 12),sink]:0.462907
# y[source,('三多復興路口', 13)]:0.866667
# y[('三多復興路口', 13),sink]:0.520587
# y[source,('三多復興路口', 14)]:0.933333
# y[('三多復興路口', 14),sink]:0.579551
# y[source,('三多復興路口', 16)]:0.066667
# y[source,('三多復興路口', 17)]:0.133333
# y[('三多復興路口', 17),sink]:0.027211
# y[source,('三多復興路口', 18)]:0.200000
# y[('三多復興路口', 18),sink]:0.051895
# y[source,('三多復興路口', 19)]:0.266667
# y[('三多復興路口', 19),sink]:0.082577
# y[source,('三多復興路口', 20)]:0.333333
# y[('三多復興路口', 20),sink]:0.118399
# y[source,('三多復興路口', 21)]:0.400000
# y[('三多復興路口', 21),sink]:0.158628
# y[source,('三多復興路口', 22)]:0.466667
# y[('三多復興路口', 22),sink]:0.202633
# y[source,('三多復興路口', 23)]:0.533333
# y[('三多復興路口', 23),sink]:0.249876
# y[source,('三多復興路口', 24)]:0.600000
# y[('三多復興路口', 24),sink]:0.299894
# y[source,('三多復興路口', 25)]:0.666667
# y[('三多復興路口', 25),sink]:0.352290
# y[source,('三多復興路口', 26)]:0.733333
# y[('三多復興路口', 26),sink]:0.406725
# y[source,('三多復興路口', 27)]:0.800000
# y[source,('三多復興路口', 28)]:0.866667
# y[('三多復興路口', 28),sink]:0.123810
# y[source,('三多復興路口', 29)]:0.933333
# y[('三多復興路口', 29),sink]:0.239456
# y[('三多復興路口', 30),sink]:0.205248
# y[source,('三多復興路口', 31)]:0.133333
# y[('三多復興路口', 31),sink]:0.194974
# y[source,('三多復興路口', 32)]:0.266667
# y[('三多復興路口', 32),sink]:0.205216
# y[source,('三多復興路口', 33)]:0.400000
# y[('三多復興路口', 33),sink]:0.233042
# y[source,('三多復興路口', 34)]:0.533333
# y[('三多復興路口', 34),sink]:0.275941
# y[source,('三多復興路口', 35)]:0.666667
# y[('三多復興路口', 35),sink]:0.331759
# y[source,('三多復興路口', 36)]:0.800000
# y[('三多復興路口', 36),sink]:0.398651
# y[source,('三多復興路口', 37)]:0.933333
# y[('三多復興路口', 37),sink]:0.475034
# y[source,('三多復興路口', 38)]:1.066667
# y[('三多復興路口', 38),sink]:0.559553
# y[source,('三多復興路口', 39)]:1.200000
# y[('三多復興路口', 39),sink]:0.651045
# y[source,('三多復興路口', 40)]:1.333333
# y[('三多復興路口', 40),sink]:0.748515
# y[source,('三多復興路口', 41)]:1.466667
# y[source,('三多復興路口', 42)]:1.600000
# y[('三多復興路口', 42),sink]:0.228571
# y[source,('三多復興路口', 43)]:1.733333
# y[('三多復興路口', 43),sink]:0.443537
# y[source,('三多復興路口', 44)]:1.866667
# y[('三多復興路口', 44),sink]:4.527891
# y[source,('三多市場(三多三路)', 1)]:0.066667
# y[source,('三多市場(三多三路)', 2)]:0.133333
# y[('三多市場(三多三路)', 2),sink]:0.027211
# y[source,('三多市場(三多三路)', 3)]:0.200000
# y[('三多市場(三多三路)', 3),sink]:0.051895
# y[source,('三多市場(三多三路)', 4)]:0.266667
# y[('三多市場(三多三路)', 4),sink]:0.082577
# y[source,('三多市場(三多三路)', 5)]:0.333333
# y[('三多市場(三多三路)', 5),sink]:0.118399
# y[source,('三多市場(三多三路)', 6)]:0.400000
# y[('三多市場(三多三路)', 6),sink]:0.158628
# y[source,('三多市場(三多三路)', 7)]:0.466667
# y[('三多市場(三多三路)', 7),sink]:0.202633
# y[source,('三多市場(三多三路)', 8)]:0.533333
# y[('三多市場(三多三路)', 8),sink]:0.249876
# y[source,('三多市場(三多三路)', 9)]:0.600000
# y[('三多市場(三多三路)', 9),sink]:0.299894
# y[source,('三多市場(三多三路)', 10)]:0.666667
# y[('三多市場(三多三路)', 10),sink]:0.352290
# y[source,('三多市場(三多三路)', 11)]:0.733333
# y[('三多市場(三多三路)', 11),sink]:0.406725
# y[source,('三多市場(三多三路)', 12)]:0.800000
# y[('三多市場(三多三路)', 12),sink]:0.462907
# y[source,('三多市場(三多三路)', 13)]:0.866667
# y[('三多市場(三多三路)', 13),sink]:0.520587
# y[source,('三多市場(三多三路)', 14)]:0.933333
# y[('三多市場(三多三路)', 14),sink]:0.579551
# y[('三多市場(三多三路)', 15),sink]:0.496758
# y[source,('三多市場(三多三路)', 16)]:0.133333
# y[source,('三多市場(三多三路)', 17)]:0.266667
# y[('三多市場(三多三路)', 17),sink]:0.038095
# y[source,('三多市場(三多三路)', 18)]:0.400000
# y[('三多市場(三多三路)', 18),sink]:0.089796
# y[source,('三多市場(三多三路)', 19)]:0.533333
# y[('三多市場(三多三路)', 19),sink]:0.153158
# y[source,('三多市場(三多三路)', 20)]:0.666667
# y[('三多市場(三多三路)', 20),sink]:0.226517
# y[source,('三多市場(三多三路)', 21)]:0.800000
# y[('三多市場(三多三路)', 21),sink]:0.308443
# y[source,('三多市場(三多三路)', 22)]:0.933333
# y[('三多市場(三多三路)', 22),sink]:0.397713
# y[source,('三多市場(三多三路)', 23)]:1.066667
# y[('三多市場(三多三路)', 23),sink]:0.493278
# y[source,('三多市場(三多三路)', 24)]:1.200000
# y[('三多市場(三多三路)', 24),sink]:0.594238
# y[source,('三多市場(三多三路)', 25)]:1.333333
# y[('三多市場(三多三路)', 25),sink]:0.699823
# y[source,('三多市場(三多三路)', 26)]:1.466667
# y[('三多市場(三多三路)', 26),sink]:0.809372
# y[source,('三多市場(三多三路)', 27)]:1.600000
# y[('三多市場(三多三路)', 27),sink]:0.922319
# y[source,('三多市場(三多三路)', 28)]:1.733333
# y[source,('三多市場(三多三路)', 29)]:1.866667
# y[('三多市場(三多三路)', 29),sink]:0.266667
# y[('三多市場(三多三路)', 30),sink]:0.228571
# y[source,('三多市場(三多三路)', 31)]:0.133333
# y[('三多市場(三多三路)', 31),sink]:0.214966
# y[source,('三多市場(三多三路)', 32)]:0.266667
# y[('三多市場(三多三路)', 32),sink]:0.222352
# y[source,('三多市場(三多三路)', 33)]:0.400000
# y[('三多市場(三多三路)', 33),sink]:0.247730
# y[source,('三多市場(三多三路)', 34)]:0.533333
# y[('三多市場(三多三路)', 34),sink]:0.288531
# y[source,('三多市場(三多三路)', 35)]:0.666667
# y[('三多市場(三多三路)', 35),sink]:0.342550
# y[source,('三多市場(三多三路)', 36)]:0.800000
# y[('三多市場(三多三路)', 36),sink]:0.407900
# y[source,('三多市場(三多三路)', 37)]:0.933333
# y[('三多市場(三多三路)', 37),sink]:0.482962
# y[source,('三多市場(三多三路)', 38)]:1.066667
# y[('三多市場(三多三路)', 38),sink]:0.566348
# y[source,('三多市場(三多三路)', 39)]:1.200000
# y[('三多市場(三多三路)', 39),sink]:0.656870
# y[source,('三多市場(三多三路)', 40)]:1.333333
# y[('三多市場(三多三路)', 40),sink]:0.753508
# y[source,('三多市場(三多三路)', 41)]:1.466667
# y[('三多市場(三多三路)', 41),sink]:0.855387
# y[source,('三多市場(三多三路)', 42)]:1.600000
# y[source,('三多市場(三多三路)', 43)]:1.733333
# y[('三多市場(三多三路)', 43),sink]:0.247619
# y[source,('三多市場(三多三路)', 44)]:1.866667
# y[('三多市場(三多三路)', 44),sink]:3.352381
# y[source,('光華路口(光華夜市)', 1)]:0.133333
# y[('光華路口(光華夜市)', 1),sink]:0.019048
# y[source,('光華路口(光華夜市)', 2)]:0.266667
# y[('光華路口(光華夜市)', 2),sink]:0.054422
# y[source,('光華路口(光華夜市)', 3)]:0.400000
# y[('光華路口(光華夜市)', 3),sink]:0.103790
# y[source,('光華路口(光華夜市)', 4)]:0.533333
# y[('光華路口(光華夜市)', 4),sink]:0.165153
# y[source,('光華路口(光華夜市)', 5)]:0.666667
# y[('光華路口(光華夜市)', 5),sink]:0.236798
# y[source,('光華路口(光華夜市)', 6)]:0.800000
# y[('光華路口(光華夜市)', 6),sink]:0.317256
# y[source,('光華路口(光華夜市)', 7)]:0.933333
# y[('光華路口(光華夜市)', 7),sink]:0.405267
# y[source,('光華路口(光華夜市)', 8)]:1.066667
# y[('光華路口(光華夜市)', 8),sink]:0.499752
# y[source,('光華路口(光華夜市)', 9)]:1.200000
# y[('光華路口(光華夜市)', 9),sink]:0.599788
# y[source,('光華路口(光華夜市)', 10)]:1.333333
# y[('光華路口(光華夜市)', 10),sink]:0.704580
# y[source,('光華路口(光華夜市)', 11)]:1.466667
# y[('光華路口(光華夜市)', 11),sink]:0.813450
# y[source,('光華路口(光華夜市)', 12)]:1.600000
# y[('光華路口(光華夜市)', 12),sink]:0.925814
# y[source,('光華路口(光華夜市)', 13)]:1.733333
# y[('光華路口(光華夜市)', 13),sink]:1.041174
# y[source,('光華路口(光華夜市)', 14)]:1.866667
# y[('光華路口(光華夜市)', 14),sink]:1.159101
# y[('光華路口(光華夜市)', 15),sink]:0.993515
# y[source,('光華路口(光華夜市)', 16)]:0.133333
# y[('光華路口(光華夜市)', 16),sink]:0.870632
# y[source,('光華路口(光華夜市)', 17)]:0.266667
# y[source,('光華路口(光華夜市)', 18)]:0.400000
# y[('光華路口(光華夜市)', 18),sink]:0.057143
# y[source,('光華路口(光華夜市)', 19)]:0.533333
# y[('光華路口(光華夜市)', 19),sink]:0.125170
# y[source,('光華路口(光華夜市)', 20)]:0.666667
# y[('光華路口(光華夜市)', 20),sink]:0.202527
# y[source,('光華路口(光華夜市)', 21)]:0.800000
# y[('光華路口(光華夜市)', 21),sink]:0.287880
# y[source,('光華路口(光華夜市)', 22)]:0.933333
# y[('光華路口(光華夜市)', 22),sink]:0.380088
# y[source,('光華路口(光華夜市)', 23)]:1.066667
# y[('光華路口(光華夜市)', 23),sink]:0.478170
# y[source,('光華路口(光華夜市)', 24)]:1.200000
# y[('光華路口(光華夜市)', 24),sink]:0.581289
# y[source,('光華路口(光華夜市)', 25)]:1.333333
# y[('光華路口(光華夜市)', 25),sink]:0.688724
# y[source,('光華路口(光華夜市)', 26)]:1.466667
# y[('光華路口(光華夜市)', 26),sink]:0.799859
# y[source,('光華路口(光華夜市)', 27)]:1.600000
# y[('光華路口(光華夜市)', 27),sink]:0.914164
# y[source,('光華路口(光華夜市)', 28)]:1.733333
# y[('光華路口(光華夜市)', 28),sink]:1.031189
# y[source,('光華路口(光華夜市)', 29)]:1.866667
# y[source,('光華路口(光華夜市)', 31)]:0.133333
# y[('光華路口(光華夜市)', 31),sink]:0.019048
# y[source,('光華路口(光華夜市)', 32)]:0.266667
# y[('光華路口(光華夜市)', 32),sink]:0.054422
# y[source,('光華路口(光華夜市)', 33)]:0.400000
# y[('光華路口(光華夜市)', 33),sink]:0.103790
# y[source,('光華路口(光華夜市)', 34)]:0.533333
# y[('光華路口(光華夜市)', 34),sink]:0.165153
# y[source,('光華路口(光華夜市)', 35)]:0.666667
# y[('光華路口(光華夜市)', 35),sink]:0.236798
# y[source,('光華路口(光華夜市)', 36)]:0.800000
# y[('光華路口(光華夜市)', 36),sink]:0.317256
# y[source,('光華路口(光華夜市)', 37)]:0.933333
# y[('光華路口(光華夜市)', 37),sink]:0.405267
# y[source,('光華路口(光華夜市)', 38)]:1.066667
# y[('光華路口(光華夜市)', 38),sink]:0.499752
# y[source,('光華路口(光華夜市)', 39)]:1.200000
# y[('光華路口(光華夜市)', 39),sink]:0.599788
# y[source,('光華路口(光華夜市)', 40)]:1.333333
# y[('光華路口(光華夜市)', 40),sink]:0.704580
# y[source,('光華路口(光華夜市)', 41)]:1.466667
# y[('光華路口(光華夜市)', 41),sink]:0.813450
# y[source,('光華路口(光華夜市)', 42)]:1.600000
# y[('光華路口(光華夜市)', 42),sink]:0.925814
# y[source,('光華路口(光華夜市)', 43)]:1.733333
# y[source,('光華路口(光華夜市)', 44)]:1.866667
# y[('光華路口(光華夜市)', 44),sink]:1.866667
# y[source,('林德官(三和市場)', 1)]:0.133333
# y[('林德官(三和市場)', 1),sink]:0.019048
# y[source,('林德官(三和市場)', 2)]:0.266667
# y[('林德官(三和市場)', 2),sink]:0.054422
# y[source,('林德官(三和市場)', 3)]:0.400000
# y[('林德官(三和市場)', 3),sink]:0.103790
# y[source,('林德官(三和市場)', 4)]:0.533333
# y[('林德官(三和市場)', 4),sink]:0.165153
# y[source,('林德官(三和市場)', 5)]:0.666667
# y[('林德官(三和市場)', 5),sink]:0.236798
# y[source,('林德官(三和市場)', 6)]:0.800000
# y[('林德官(三和市場)', 6),sink]:0.317256
# y[source,('林德官(三和市場)', 7)]:0.933333
# y[('林德官(三和市場)', 7),sink]:0.405267
# y[source,('林德官(三和市場)', 8)]:1.066667
# y[('林德官(三和市場)', 8),sink]:0.499752
# y[source,('林德官(三和市場)', 9)]:1.200000
# y[('林德官(三和市場)', 9),sink]:0.599788
# y[source,('林德官(三和市場)', 10)]:1.333333
# y[('林德官(三和市場)', 10),sink]:0.704580
# y[source,('林德官(三和市場)', 11)]:1.466667
# y[('林德官(三和市場)', 11),sink]:0.813450
# y[source,('林德官(三和市場)', 12)]:1.600000
# y[('林德官(三和市場)', 12),sink]:0.925814
# y[source,('林德官(三和市場)', 13)]:1.733333
# y[('林德官(三和市場)', 13),sink]:1.041174
# y[source,('林德官(三和市場)', 14)]:1.866667
# y[('林德官(三和市場)', 14),sink]:1.159101
# y[('林德官(三和市場)', 15),sink]:0.993515
# y[source,('林德官(三和市場)', 16)]:0.133333
# y[('林德官(三和市場)', 16),sink]:0.870632
# y[source,('林德官(三和市場)', 17)]:0.266667
# y[source,('林德官(三和市場)', 18)]:0.400000
# y[('林德官(三和市場)', 18),sink]:0.057143
# y[source,('林德官(三和市場)', 19)]:0.533333
# y[('林德官(三和市場)', 19),sink]:0.125170
# y[source,('林德官(三和市場)', 20)]:0.666667
# y[('林德官(三和市場)', 20),sink]:0.202527
# y[source,('林德官(三和市場)', 21)]:0.800000
# y[('林德官(三和市場)', 21),sink]:0.287880
# y[source,('林德官(三和市場)', 22)]:0.933333
# y[('林德官(三和市場)', 22),sink]:0.380088
# y[source,('林德官(三和市場)', 23)]:1.066667
# y[('林德官(三和市場)', 23),sink]:0.478170
# y[source,('林德官(三和市場)', 24)]:1.200000
# y[('林德官(三和市場)', 24),sink]:0.581289
# y[source,('林德官(三和市場)', 25)]:1.333333
# y[('林德官(三和市場)', 25),sink]:0.688724
# y[source,('林德官(三和市場)', 26)]:1.466667
# y[('林德官(三和市場)', 26),sink]:0.799859
# y[source,('林德官(三和市場)', 27)]:1.600000
# y[('林德官(三和市場)', 27),sink]:0.914164
# y[source,('林德官(三和市場)', 28)]:1.733333
# y[('林德官(三和市場)', 28),sink]:1.031189
# y[source,('林德官(三和市場)', 29)]:1.866667
# y[source,('林德官(三和市場)', 31)]:0.133333
# y[('林德官(三和市場)', 31),sink]:0.019048
# y[source,('林德官(三和市場)', 32)]:0.266667
# y[('林德官(三和市場)', 32),sink]:0.054422
# y[source,('林德官(三和市場)', 33)]:0.400000
# y[('林德官(三和市場)', 33),sink]:0.103790
# y[source,('林德官(三和市場)', 34)]:0.533333
# y[('林德官(三和市場)', 34),sink]:0.165153
# y[source,('林德官(三和市場)', 35)]:0.666667
# y[('林德官(三和市場)', 35),sink]:0.236798
# y[source,('林德官(三和市場)', 36)]:0.800000
# y[('林德官(三和市場)', 36),sink]:0.317256
# y[source,('林德官(三和市場)', 37)]:0.933333
# y[('林德官(三和市場)', 37),sink]:0.405267
# y[source,('林德官(三和市場)', 38)]:1.066667
# y[('林德官(三和市場)', 38),sink]:0.499752
# y[source,('林德官(三和市場)', 39)]:1.200000
# y[('林德官(三和市場)', 39),sink]:0.599788
# y[source,('林德官(三和市場)', 40)]:1.333333
# y[('林德官(三和市場)', 40),sink]:0.704580
# y[source,('林德官(三和市場)', 41)]:1.466667
# y[('林德官(三和市場)', 41),sink]:0.813450
# y[source,('林德官(三和市場)', 42)]:1.600000
# y[('林德官(三和市場)', 42),sink]:0.925814
# y[source,('林德官(三和市場)', 43)]:1.733333
# y[source,('林德官(三和市場)', 44)]:1.866667
# y[('林德官(三和市場)', 44),sink]:1.866667
# y[source,('和平路口', 1)]:0.066667
# y[source,('和平路口', 2)]:0.133333
# y[('和平路口', 2),sink]:0.027211
# y[source,('和平路口', 3)]:0.200000
# y[('和平路口', 3),sink]:0.051895
# ...
# y[('五權國小(三多二路)', 32),('五權國小(三多二路)', 33)]:0.228571
# y[('五權國小(三多二路)', 33),('五權國小(三多二路)', 34)]:0.538776
# y[('五權國小(三多二路)', 34),('五權國小(三多二路)', 35)]:0.918950
# y[('五權國小(三多二路)', 35),('五權國小(三多二路)', 36)]:1.359100
# y[('五權國小(三多二路)', 36),('五權國小(三多二路)', 37)]:1.850657
# y[('五權國小(三多二路)', 37),('五權國小(三多二路)', 38)]:2.386278
# y[('五權國小(三多二路)', 38),('五權國小(三多二路)', 39)]:2.959667
# y[('五權國小(三多二路)', 39),('五權國小(三多二路)', 40)]:3.565429
# y[('五權國小(三多二路)', 40),('五權國小(三多二路)', 41)]:4.198939
# y[('五權國小(三多二路)', 41),('五權國小(三多二路)', 42)]:4.856233
# y[('五權國小(三多二路)', 42),('五權國小(三多二路)', 43)]:5.533914
# y[('五權國小(三多二路)', 43),('五權國小(三多二路)', 44)]:6.229069
# y[('國際商工', 1),('國際商工', 2)]:0.057143
# y[('國際商工', 2),('國際商工', 3)]:0.163265
# y[('國際商工', 3),('國際商工', 4)]:0.311370
# y[('國際商工', 4),('國際商工', 5)]:0.495460
# y[('國際商工', 5),('國際商工', 6)]:0.710394
# y[('國際商工', 6),('國際商工', 7)]:0.951767
# y[('國際商工', 7),('國際商工', 8)]:1.215800
# y[('國際商工', 8),('國際商工', 9)]:1.499257
# y[('國際商工', 9),('國際商工', 10)]:1.799363
# y[('國際商工', 10),('國際商工', 11)]:2.113740
# y[('國際商工', 11),('國際商工', 12)]:2.440349
# y[('國際商工', 12),('國際商工', 13)]:2.777442
# y[('國際商工', 13),('國際商工', 14)]:3.123521
# y[('國際商工', 14),('國際商工', 15)]:3.477304
# y[('國際商工', 15),('國際商工', 16)]:2.980546
# y[('國際商工', 16),('國際商工', 17)]:2.611897
# y[('國際商工', 17),('國際商工', 18)]:2.353054
# y[('國際商工', 18),('國際商工', 19)]:2.188332
# y[('國際商工', 19),('國際商工', 20)]:2.104285
# y[('國際商工', 21),('國際商工', 22)]:0.342857
# y[('國際商工', 22),('國際商工', 23)]:0.693878
# y[('國際商工', 23),('國際商工', 24)]:1.051895
# y[('國際商工', 24),('國際商工', 25)]:1.415910
# y[('國際商工', 25),('國際商工', 26)]:1.785066
# y[('國際商工', 26),('國際商工', 27)]:2.158628
# y[('國際商工', 27),('國際商工', 28)]:2.535967
# y[('國際商工', 28),('國際商工', 29)]:2.916543
# y[('國際商工', 29),('國際商工', 30)]:3.299894
# y[('國際商工', 30),('國際商工', 31)]:2.828480
# y[('國際商工', 31),('國際商工', 32)]:2.481555
# y[('國際商工', 33),('國際商工', 34)]:0.171429
# y[('國際商工', 34),('國際商工', 35)]:0.375510
# y[('國際商工', 35),('國際商工', 36)]:0.607580
# y[('國際商工', 36),('國際商工', 37)]:0.863640
# y[('國際商工', 37),('國際商工', 38)]:1.140263
# y[('國際商工', 38),('國際商工', 39)]:1.434511
# y[('國際商工', 39),('國際商工', 40)]:1.743867
# y[('國際商工', 40),('國際商工', 41)]:2.066171
# y[('國際商工', 41),('國際商工', 42)]:2.399576
# y[('國際商工', 42),('國際商工', 43)]:2.742493
# y[('國際商工', 43),('國際商工', 44)]:3.093566
# y[('三信家商', 1),('三信家商', 2)]:0.114286
# y[('三信家商', 2),('三信家商', 3)]:0.326531
# y[('三信家商', 3),('三信家商', 4)]:0.622741
# y[('三信家商', 4),('三信家商', 5)]:0.990920
# y[('三信家商', 5),('三信家商', 6)]:1.420789
# y[('三信家商', 6),('三信家商', 7)]:1.903533
# y[('三信家商', 7),('三信家商', 8)]:2.431600
# y[('三信家商', 8),('三信家商', 9)]:2.998514
# y[('三信家商', 9),('三信家商', 10)]:3.598727
# y[('三信家商', 10),('三信家商', 11)]:4.227480
# y[('三信家商', 11),('三信家商', 12)]:4.880697
# y[('三信家商', 12),('三信家商', 13)]:5.554883
# y[('三信家商', 13),('三信家商', 14)]:6.247043
# y[('三信家商', 14),('三信家商', 15)]:6.954608
# y[('三信家商', 15),('三信家商', 16)]:5.961093
# y[('三信家商', 16),('三信家商', 17)]:5.223794
# y[('三信家商', 17),('三信家商', 18)]:4.706109
# y[('三信家商', 18),('三信家商', 19)]:4.376665
# y[('三信家商', 19),('三信家商', 20)]:4.208570
# y[('三信家商', 20),('三信家商', 21)]:4.178774
# y[('三信家商', 22),('三信家商', 23)]:0.800000
# y[('三信家商', 23),('三信家商', 24)]:1.600000
# y[('三信家商', 24),('三信家商', 25)]:2.400000
# y[('三信家商', 25),('三信家商', 26)]:3.200000
# y[('三信家商', 26),('三信家商', 27)]:4.000000
# y[('三信家商', 27),('三信家商', 28)]:4.800000
# y[('三信家商', 28),('三信家商', 29)]:5.600000
# y[('三信家商', 29),('三信家商', 30)]:6.400000
# y[('三信家商', 30),('三信家商', 31)]:5.485714
# y[('三信家商', 31),('三信家商', 32)]:4.759184
# y[('三信家商', 32),('三信家商', 33)]:4.193586
# y[('三信家商', 34),('三信家商', 35)]:0.228571
# y[('三信家商', 35),('三信家商', 36)]:0.481633
# y[('三信家商', 36),('三信家商', 37)]:0.755685
# y[('三信家商', 37),('三信家商', 38)]:1.047730
# y[('三信家商', 38),('三信家商', 39)]:1.355197
# y[('三信家商', 39),('三信家商', 40)]:1.675883
# y[('三信家商', 40),('三信家商', 41)]:2.007900
# y[('三信家商', 41),('三信家商', 42)]:2.349629
# y[('三信家商', 42),('三信家商', 43)]:2.699682
# y[('三信家商', 43),('三信家商', 44)]:3.056870
# y[('五塊厝(三多一路)', 1),('五塊厝(三多一路)', 2)]:0.057143
# y[('五塊厝(三多一路)', 2),('五塊厝(三多一路)', 3)]:0.163265
# y[('五塊厝(三多一路)', 3),('五塊厝(三多一路)', 4)]:0.311370
# y[('五塊厝(三多一路)', 4),('五塊厝(三多一路)', 5)]:0.495460
# y[('五塊厝(三多一路)', 5),('五塊厝(三多一路)', 6)]:0.710394
# y[('五塊厝(三多一路)', 6),('五塊厝(三多一路)', 7)]:0.951767
# y[('五塊厝(三多一路)', 7),('五塊厝(三多一路)', 8)]:1.215800
# y[('五塊厝(三多一路)', 8),('五塊厝(三多一路)', 9)]:1.499257
# y[('五塊厝(三多一路)', 9),('五塊厝(三多一路)', 10)]:1.799363
# y[('五塊厝(三多一路)', 10),('五塊厝(三多一路)', 11)]:2.113740
# y[('五塊厝(三多一路)', 11),('五塊厝(三多一路)', 12)]:2.440349
# y[('五塊厝(三多一路)', 12),('五塊厝(三多一路)', 13)]:2.777442
# y[('五塊厝(三多一路)', 13),('五塊厝(三多一路)', 14)]:3.123521
# y[('五塊厝(三多一路)', 14),('五塊厝(三多一路)', 15)]:3.477304
# y[('五塊厝(三多一路)', 15),('五塊厝(三多一路)', 16)]:2.980546
# y[('五塊厝(三多一路)', 16),('五塊厝(三多一路)', 17)]:2.554754
# y[('五塊厝(三多一路)', 17),('五塊厝(三多一路)', 18)]:2.189789
# y[('五塊厝(三多一路)', 18),('五塊厝(三多一路)', 19)]:1.876962
# y[('五塊厝(三多一路)', 19),('五塊厝(三多一路)', 20)]:1.608825
# y[('五塊厝(三多一路)', 20),('五塊厝(三多一路)', 21)]:1.378993
# y[('五塊厝(三多一路)', 21),('五塊厝(三多一路)', 22)]:1.181994
# y[('五塊厝(三多一路)', 31),('五塊厝(三多一路)', 32)]:0.057143
# y[('五塊厝(三多一路)', 32),('五塊厝(三多一路)', 33)]:0.163265
# y[('五塊厝(三多一路)', 33),('五塊厝(三多一路)', 34)]:0.311370
# y[('五塊厝(三多一路)', 35),('五塊厝(三多一路)', 36)]:0.285714
# y[('五塊厝(三多一路)', 36),('五塊厝(三多一路)', 37)]:0.587755
# y[('五塊厝(三多一路)', 37),('五塊厝(三多一路)', 38)]:0.903790
# y[('五塊厝(三多一路)', 38),('五塊厝(三多一路)', 39)]:1.231820
# y[('五塊厝(三多一路)', 39),('五塊厝(三多一路)', 40)]:1.570131
# y[('五塊厝(三多一路)', 40),('五塊厝(三多一路)', 41)]:1.917256
# y[('五塊厝(三多一路)', 41),('五塊厝(三多一路)', 42)]:2.271933
# y[('五塊厝(三多一路)', 42),('五塊厝(三多一路)', 43)]:2.633086
# y[('五塊厝(三多一路)', 43),('五塊厝(三多一路)', 44)]:2.999788
# y[('輔仁路口(三多一路)', 1),('輔仁路口(三多一路)', 2)]:0.057143
# y[('輔仁路口(三多一路)', 2),('輔仁路口(三多一路)', 3)]:0.163265
# y[('輔仁路口(三多一路)', 3),('輔仁路口(三多一路)', 4)]:0.311370
# y[('輔仁路口(三多一路)', 4),('輔仁路口(三多一路)', 5)]:0.495460
# y[('輔仁路口(三多一路)', 5),('輔仁路口(三多一路)', 6)]:0.710394
# y[('輔仁路口(三多一路)', 6),('輔仁路口(三多一路)', 7)]:0.951767
# y[('輔仁路口(三多一路)', 7),('輔仁路口(三多一路)', 8)]:1.215800
# y[('輔仁路口(三多一路)', 8),('輔仁路口(三多一路)', 9)]:1.499257
# y[('輔仁路口(三多一路)', 9),('輔仁路口(三多一路)', 10)]:1.799363
# y[('輔仁路口(三多一路)', 10),('輔仁路口(三多一路)', 11)]:2.113740
# y[('輔仁路口(三多一路)', 11),('輔仁路口(三多一路)', 12)]:2.440349
# y[('輔仁路口(三多一路)', 12),('輔仁路口(三多一路)', 13)]:2.777442
# y[('輔仁路口(三多一路)', 13),('輔仁路口(三多一路)', 14)]:3.123521
# y[('輔仁路口(三多一路)', 14),('輔仁路口(三多一路)', 15)]:3.477304
# y[('輔仁路口(三多一路)', 15),('輔仁路口(三多一路)', 16)]:2.980546
# y[('輔仁路口(三多一路)', 16),('輔仁路口(三多一路)', 17)]:2.611897
# y[('輔仁路口(三多一路)', 17),('輔仁路口(三多一路)', 18)]:2.353054
# y[('輔仁路口(三多一路)', 18),('輔仁路口(三多一路)', 19)]:2.188332
# y[('輔仁路口(三多一路)', 19),('輔仁路口(三多一路)', 20)]:2.104285
# y[('輔仁路口(三多一路)', 20),('輔仁路口(三多一路)', 21)]:2.089387
# y[('輔仁路口(三多一路)', 21),('輔仁路口(三多一路)', 22)]:2.133760
# y[('輔仁路口(三多一路)', 22),('輔仁路口(三多一路)', 23)]:2.228937
# y[('輔仁路口(三多一路)', 24),('輔仁路口(三多一路)', 25)]:0.514286
# y[('輔仁路口(三多一路)', 25),('輔仁路口(三多一路)', 26)]:1.012245
# y[('輔仁路口(三多一路)', 26),('輔仁路口(三多一路)', 27)]:1.496210
# y[('輔仁路口(三多一路)', 27),('輔仁路口(三多一路)', 28)]:1.968180
# y[('輔仁路口(三多一路)', 28),('輔仁路口(三多一路)', 29)]:2.429869
# y[('輔仁路口(三多一路)', 29),('輔仁路口(三多一路)', 30)]:2.882744
# y[('輔仁路口(三多一路)', 30),('輔仁路口(三多一路)', 31)]:2.470924
# y[('輔仁路口(三多一路)', 31),('輔仁路口(三多一路)', 32)]:2.117935
# y[('輔仁路口(三多一路)', 32),('輔仁路口(三多一路)', 33)]:1.815373
# y[('輔仁路口(三多一路)', 33),('輔仁路口(三多一路)', 34)]:1.556034
# y[('輔仁路口(三多一路)', 34),('輔仁路口(三多一路)', 35)]:1.333743
# y[('中正體育場', 1),('中正體育場', 2)]:0.057143
# y[('中正體育場', 2),('中正體育場', 3)]:0.163265
# y[('中正體育場', 3),('中正體育場', 4)]:0.311370
# y[('中正體育場', 4),('中正體育場', 5)]:0.495460
# y[('中正體育場', 5),('中正體育場', 6)]:0.710394
# y[('中正體育場', 6),('中正體育場', 7)]:0.951767
# y[('中正體育場', 7),('中正體育場', 8)]:1.215800
# y[('中正體育場', 8),('中正體育場', 9)]:1.499257
# y[('中正體育場', 9),('中正體育場', 10)]:1.799363
# y[('中正體育場', 10),('中正體育場', 11)]:2.113740
# y[('中正體育場', 11),('中正體育場', 12)]:2.440349
# y[('中正體育場', 12),('中正體育場', 13)]:2.777442
# y[('中正體育場', 13),('中正體育場', 14)]:3.123521
# y[('中正體育場', 14),('中正體育場', 15)]:3.477304
# y[('中正體育場', 15),('中正體育場', 16)]:2.980546
# y[('中正體育場', 16),('中正體育場', 17)]:2.611897
# y[('中正體育場', 17),('中正體育場', 18)]:2.353054
# y[('中正體育場', 18),('中正體育場', 19)]:2.188332
# y[('中正體育場', 19),('中正體育場', 20)]:2.104285
# y[('中正體育場', 20),('中正體育場', 21)]:2.089387
# y[('中正體育場', 21),('中正體育場', 22)]:2.133760
# y[('中正體育場', 22),('中正體育場', 23)]:2.228937
# y[('中正體育場', 23),('中正體育場', 24)]:2.367661
# y[('中正體育場', 25),('中正體育場', 26)]:0.571429
# y[('中正體育場', 26),('中正體育場', 27)]:1.118367
# y[('中正體育場', 27),('中正體育場', 28)]:1.644315
# y[('中正體育場', 28),('中正體育場', 29)]:2.152270
# y[('中正體育場', 29),('中正體育場', 30)]:2.644803
# y[('中正體育場', 30),('中正體育場', 31)]:2.266974
# y[('中正體育場', 31),('中正體育場', 32)]:2.000263
# y[('中正體育場', 32),('中正體育場', 33)]:1.828797
# y[('中正體育場', 33),('中正體育場', 34)]:1.738969
# y[('中正體育場', 34),('中正體育場', 35)]:1.719116
# y[('中正體育場', 35),('中正體育場', 36)]:1.759242
# y[('中正體育場', 37),('中正體育場', 38)]:0.400000
# y[('中正體育場', 38),('中正體育場', 39)]:0.800000
# y[('中正體育場', 39),('中正體育場', 40)]:1.200000
# y[('中正體育場', 40),('中正體育場', 41)]:1.600000
# y[('中正體育場', 41),('中正體育場', 42)]:2.000000
# y[('中正體育場', 42),('中正體育場', 43)]:2.400000
# y[('中正體育場', 43),('中正體育場', 44)]:2.800000
# y[('衛武營國家藝術文化中心', 1),('衛武營國家藝術文化中心', 2)]:0.114286
# y[('衛武營國家藝術文化中心', 2),('衛武營國家藝術文化中心', 3)]:0.326531
# y[('衛武營國家藝術文化中心', 3),('衛武營國家藝術文化中心', 4)]:0.622741
# y[('衛武營國家藝術文化中心', 4),('衛武營國家藝術文化中心', 5)]:0.990920
# y[('衛武營國家藝術文化中心', 5),('衛武營國家藝術文化中心', 6)]:1.420789
# y[('衛武營國家藝術文化中心', 6),('衛武營國家藝術文化中心', 7)]:1.903533
# y[('衛武營國家藝術文化中心', 7),('衛武營國家藝術文化中心', 8)]:2.431600
# y[('衛武營國家藝術文化中心', 8),('衛武營國家藝術文化中心', 9)]:2.998514
# y[('衛武營國家藝術文化中心', 9),('衛武營國家藝術文化中心', 10)]:3.598727
# y[('衛武營國家藝術文化中心', 10),('衛武營國家藝術文化中心', 11)]:4.227480
# y[('衛武營國家藝術文化中心', 11),('衛武營國家藝術文化中心', 12)]:4.880697
# y[('衛武營國家藝術文化中心', 12),('衛武營國家藝術文化中心', 13)]:5.554883
# y[('衛武營國家藝術文化中心', 13),('衛武營國家藝術文化中心', 14)]:6.247043
# y[('衛武營國家藝術文化中心', 14),('衛武營國家藝術文化中心', 15)]:6.954608
# y[('衛武營國家藝術文化中心', 15),('衛武營國家藝術文化中心', 16)]:5.961093
# y[('衛武營國家藝術文化中心', 16),('衛武營國家藝術文化中心', 17)]:5.223794
# y[('衛武營國家藝術文化中心', 17),('衛武營國家藝術文化中心', 18)]:4.706109
# y[('衛武營國家藝術文化中心', 18),('衛武營國家藝術文化中心', 19)]:4.376665
# y[('衛武營國家藝術文化中心', 19),('衛武營國家藝術文化中心', 20)]:4.208570
# y[('衛武營國家藝術文化中心', 20),('衛武營國家藝術文化中心', 21)]:4.178774
# y[('衛武營國家藝術文化中心', 21),('衛武營國家藝術文化中心', 22)]:4.267521
# y[('衛武營國家藝術文化中心', 22),('衛武營國家藝術文化中心', 23)]:4.457875
# y[('衛武營國家藝術文化中心', 23),('衛武營國家藝術文化中心', 24)]:4.735321
# y[('衛武營國家藝術文化中心', 24),('衛武營國家藝術文化中心', 25)]:5.087418
# y[('衛武營國家藝術文化中心', 25),('衛武營國家藝術文化中心', 26)]:5.503501
# y[('衛武營國家藝術文化中心', 27),('衛武營國家藝術文化中心', 28)]:1.371429
# y[('衛武營國家藝術文化中心', 28),('衛武營國家藝術文化中心', 29)]:2.661224
# y[('衛武營國家藝術文化中心', 29),('衛武營國家藝術文化中心', 30)]:3.881050
# y[('衛武營國家藝術文化中心', 30),('衛武營國家藝術文化中心', 31)]:3.326614
# y[('衛武營國家藝術文化中心', 31),('衛武營國家藝術文化中心', 32)]:2.965669
# y[('衛武營國家藝術文化中心', 32),('衛武營國家藝術文化中心', 33)]:2.770573
# y[('衛武營國家藝術文化中心', 33),('衛武營國家藝術文化中心', 34)]:2.717634
# y[('衛武營國家藝術文化中心', 34),('衛武營國家藝術文化中心', 35)]:2.786544
# y[('衛武營國家藝術文化中心', 35),('衛武營國家藝術文化中心', 36)]:2.959895
# y[('衛武營國家藝術文化中心', 36),('衛武營國家藝術文化中心', 37)]:3.222767
# y[('衛武營國家藝術文化中心', 37),('衛武營國家藝術文化中心', 38)]:3.562372
# y[('衛武營國家藝術文化中心', 39),('衛武營國家藝術文化中心', 40)]:1.028571
# y[('衛武營國家藝術文化中心', 40),('衛武營國家藝術文化中心', 41)]:2.024490
# y[('衛武營國家藝術文化中心', 41),('衛武營國家藝術文化中心', 42)]:2.992420
# y[('衛武營國家藝術文化中心', 42),('衛武營國家藝術文化中心', 43)]:3.936360
# y[('衛武社區', 1),('衛武社區', 2)]:0.057143
# y[('衛武社區', 2),('衛武社區', 3)]:0.163265
# y[('衛武社區', 3),('衛武社區', 4)]:0.311370
# y[('衛武社區', 4),('衛武社區', 5)]:0.495460
# y[('衛武社區', 5),('衛武社區', 6)]:0.710394
# y[('衛武社區', 6),('衛武社區', 7)]:0.951767
# y[('衛武社區', 7),('衛武社區', 8)]:1.215800
# y[('衛武社區', 8),('衛武社區', 9)]:1.499257
# y[('衛武社區', 9),('衛武社區', 10)]:1.799363
# y[('衛武社區', 10),('衛武社區', 11)]:2.113740
# y[('衛武社區', 11),('衛武社區', 12)]:2.440349
# y[('衛武社區', 12),('衛武社區', 13)]:2.777442
# y[('衛武社區', 13),('衛武社區', 14)]:3.123521
# y[('衛武社區', 14),('衛武社區', 15)]:3.477304
# y[('衛武社區', 15),('衛武社區', 16)]:2.980546
# y[('衛武社區', 16),('衛武社區', 17)]:2.611897
# y[('衛武社區', 17),('衛武社區', 18)]:2.353054
# y[('衛武社區', 18),('衛武社區', 19)]:2.188332
# y[('衛武社區', 19),('衛武社區', 20)]:2.104285
# y[('衛武社區', 20),('衛武社區', 21)]:2.089387
# y[('衛武社區', 21),('衛武社區', 22)]:2.133760
# y[('衛武社區', 22),('衛武社區', 23)]:2.228937
# y[('衛武社區', 23),('衛武社區', 24)]:2.367661
# y[('衛武社區', 24),('衛武社區', 25)]:2.543709
# y[('衛武社區', 25),('衛武社區', 26)]:2.751751
# y[('衛武社區', 26),('衛武社區', 27)]:2.987215
# y[('衛武社區', 27),('衛武社區', 28)]:3.246184
# y[('衛武社區', 28),('衛武社區', 29)]:3.525301
# y[('衛武社區', 31),('衛武社區', 32)]:0.057143
# y[('衛武社區', 32),('衛武社區', 33)]:0.163265
# y[('衛武社區', 33),('衛武社區', 34)]:0.311370
# y[('衛武社區', 34),('衛武社區', 35)]:0.495460
# y[('衛武社區', 35),('衛武社區', 36)]:0.710394
# y[('衛武社區', 36),('衛武社區', 37)]:0.951767
# y[('衛武社區', 37),('衛武社區', 38)]:1.215800
# y[('衛武社區', 38),('衛武社區', 39)]:1.499257
# y[('衛武社區', 39),('衛武社區', 40)]:1.799363
# y[('衛武社區', 40),('衛武社區', 41)]:2.113740
# y[('衛武社區', 42),('衛武社區', 43)]:0.685714
# y[('衛武社區', 43),('衛武社區', 44)]:1.330612
# y[('鳳山行政中心(澄清路)', 16),('鳳山行政中心(澄清路)', 17)]:0.057143
# y[('鳳山行政中心(澄清路)', 17),('鳳山行政中心(澄清路)', 18)]:0.163265
# y[('鳳山行政中心(澄清路)', 18),('鳳山行政中心(澄清路)', 19)]:0.311370
# y[('鳳山行政中心(澄清路)', 19),('鳳山行政中心(澄清路)', 20)]:0.495460
# y[('鳳山行政中心(澄清路)', 20),('鳳山行政中心(澄清路)', 21)]:0.710394
# y[('鳳山行政中心(澄清路)', 21),('鳳山行政中心(澄清路)', 22)]:0.951767
# y[('鳳山行政中心(澄清路)', 22),('鳳山行政中心(澄清路)', 23)]:1.215800
# y[('鳳山行政中心(澄清路)', 23),('鳳山行政中心(澄清路)', 24)]:1.499257
# y[('鳳山行政中心(澄清路)', 24),('鳳山行政中心(澄清路)', 25)]:1.799363
# y[('鳳山行政中心(澄清路)', 25),('鳳山行政中心(澄清路)', 26)]:2.113740
# y[('鳳山行政中心(澄清路)', 26),('鳳山行政中心(澄清路)', 27)]:2.440349
# y[('鳳山行政中心(澄清路)', 27),('鳳山行政中心(澄清路)', 28)]:2.777442
# y[('鳳山行政中心(澄清路)', 28),('鳳山行政中心(澄清路)', 29)]:3.123521
# y[('鳳山行政中心(澄清路)', 29),('鳳山行政中心(澄清路)', 30)]:3.477304
# y[('鳳山行政中心(澄清路)', 30),('鳳山行政中心(澄清路)', 31)]:2.980546
# y[('鳳山行政中心(澄清路)', 32),('鳳山行政中心(澄清路)', 33)]:0.114286
# y[('鳳山行政中心(澄清路)', 33),('鳳山行政中心(澄清路)', 34)]:0.269388
# y[('鳳山行政中心(澄清路)', 34),('鳳山行政中心(澄清路)', 35)]:0.459475
# y[('鳳山行政中心(澄清路)', 35),('鳳山行政中心(澄清路)', 36)]:0.679550
# y[('鳳山行政中心(澄清路)', 36),('鳳山行政中心(澄清路)', 37)]:0.925329
# y[('鳳山行政中心(澄清路)', 37),('鳳山行政中心(澄清路)', 38)]:1.193139
# y[('鳳山行政中心(澄清路)', 38),('鳳山行政中心(澄清路)', 39)]:1.479833
# y[('鳳山行政中心(澄清路)', 39),('鳳山行政中心(澄清路)', 40)]:1.782714
# y[('鳳山行政中心(澄清路)', 40),('鳳山行政中心(澄清路)', 41)]:2.099469
# y[('鳳山行政中心(澄清路)', 41),('鳳山行政中心(澄清路)', 42)]:2.428117
# y[('鳳山行政中心(澄清路)', 42),('鳳山行政中心(澄清路)', 43)]:2.766957
# y[('澄清路', 16),('澄清路', 17)]:0.057143
# y[('澄清路', 17),('澄清路', 18)]:0.163265
# y[('澄清路', 18),('澄清路', 19)]:0.311370
# y[('澄清路', 19),('澄清路', 20)]:0.495460
# y[('澄清路', 20),('澄清路', 21)]:0.710394
# y[('澄清路', 21),('澄清路', 22)]:0.951767
# y[('澄清路', 22),('澄清路', 23)]:1.215800
# y[('澄清路', 23),('澄清路', 24)]:1.499257
# y[('澄清路', 24),('澄清路', 25)]:1.799363
# y[('澄清路', 25),('澄清路', 26)]:2.113740
# y[('澄清路', 26),('澄清路', 27)]:2.440349
# y[('澄清路', 27),('澄清路', 28)]:2.777442
# y[('澄清路', 28),('澄清路', 29)]:3.123521
# y[('澄清路', 29),('澄清路', 30)]:3.477304
# y[('澄清路', 30),('澄清路', 31)]:2.980546
# y[('澄清路', 31),('澄清路', 32)]:2.554754
# y[('澄清路', 32),('澄清路', 33)]:2.189789
# y[('澄清路', 33),('澄清路', 34)]:1.876962
# y[('澄清路', 34),('澄清路', 35)]:1.608825
# y[('澄清路', 35),('澄清路', 36)]:1.378993
# y[('長庚復健大樓', 1),('長庚復健大樓', 2)]:0.057143
# y[('長庚復健大樓', 2),('長庚復健大樓', 3)]:0.163265
# y[('長庚復健大樓', 3),('長庚復健大樓', 4)]:0.311370
# y[('長庚復健大樓', 4),('長庚復健大樓', 5)]:0.495460
# y[('長庚復健大樓', 5),('長庚復健大樓', 6)]:0.710394
# y[('長庚復健大樓', 6),('長庚復健大樓', 7)]:0.951767
# y[('長庚復健大樓', 7),('長庚復健大樓', 8)]:1.215800
# y[('長庚復健大樓', 8),('長庚復健大樓', 9)]:1.499257
# y[('長庚復健大樓', 9),('長庚復健大樓', 10)]:1.799363
# y[('長庚復健大樓', 10),('長庚復健大樓', 11)]:2.113740
# y[('長庚復健大樓', 11),('長庚復健大樓', 12)]:2.440349
# y[('長庚復健大樓', 12),('長庚復健大樓', 13)]:2.777442
# y[('長庚復健大樓', 13),('長庚復健大樓', 14)]:3.123521
# y[('長庚復健大樓', 14),('長庚復健大樓', 15)]:3.477304
# y[('長庚復健大樓', 15),('長庚復健大樓', 16)]:2.980546
# y[('長庚復健大樓', 16),('長庚復健大樓', 17)]:2.669040
# y[('長庚復健大樓', 17),('長庚復健大樓', 18)]:2.516320
# y[('長庚復健大樓', 18),('長庚復健大樓', 19)]:2.499703
# y[('長庚復健大樓', 19),('長庚復健大樓', 20)]:2.599745
# y[('長庚復健大樓', 20),('長庚復健大樓', 21)]:2.799782
# y[('長庚復健大樓', 21),('長庚復健大樓', 22)]:3.085527
# y[('長庚復健大樓', 22),('長庚復健大樓', 23)]:3.444737
# y[('長庚復健大樓', 23),('長庚復健大樓', 24)]:3.866918
# y[('長庚復健大樓', 24),('長庚復健大樓', 25)]:4.343072
# y[('長庚復健大樓', 25),('長庚復健大樓', 26)]:4.865491
# y[('長庚復健大樓', 26),('長庚復健大樓', 27)]:5.427563
# y[('長庚復健大樓', 27),('長庚復健大樓', 28)]:6.023626
# y[('長庚復健大樓', 28),('長庚復健大樓', 29)]:6.648822
# y[('長庚復健大樓', 29),('長庚復健大樓', 30)]:7.298990
# y[('長庚復健大樓', 30),('長庚復健大樓', 31)]:6.256277
# y[('長庚復健大樓', 31),('長庚復健大樓', 32)]:5.476809
# y[('長庚復健大樓', 32),('長庚復健大樓', 33)]:4.922979
# y[('長庚復健大樓', 33),('長庚復健大樓', 34)]:4.562554
# y[('長庚復健大樓', 34),('長庚復健大樓', 35)]:4.367903
# y[('長庚復健大樓', 35),('長庚復健大樓', 36)]:4.315346
# y[('長庚復健大樓', 36),('長庚復健大樓', 37)]:4.384582
# y[('長庚復健大樓', 37),('長庚復健大樓', 38)]:4.558213
# y[('長庚復健大樓', 38),('長庚復健大樓', 39)]:4.821326
# y[('長庚復健大樓', 39),('長庚復健大樓', 40)]:5.161136
# y[('長庚復健大樓', 40),('長庚復健大樓', 41)]:5.566688
# y[('長庚復健大樓', 41),('長庚復健大樓', 42)]:6.028590
# y[('長庚復健大樓', 42),('長庚復健大樓', 43)]:6.538791
# y[('長庚復健大樓', 43),('長庚復健大樓', 44)]:7.090393
# objective value:-5110.598592

# %% [markdown]
# ### Question

# %% [markdown]
# >1.乘客四捨五入的機制
#
# >2.旅行時間小於一分鐘的站，會有問題嗎?
#
# >3.確認個別守衡，是每個起點都一個路網[路網中的等候arc會隨業者等候時長的政策而改變，因此不需靠限制式限制等候時間上限]?[迄點固定在最後一站]
